# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import os, sys
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import statsmodels.stats.api as sms

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
path = '/nfs/turbo/umms-awaljee/wsliu/Data/NRD/'

# %%
module_path = '/home/wsliu/Codes/DLproj'
if module_path not in sys.path:
    sys.path.append(module_path)
if module_path+'/NRD' not in sys.path:
    sys.path.append(module_path+'/NRD')

# %%
from ccs_tools import core_dtypes_pd
from utils import preprocess
# Out:
# Using TensorFlow backend.

# %%
data_df = pd.read_csv(path+'cohorts/ami/ami_pred.csv', dtype=core_dtypes_pd)

# %%
DX_series = pd.concat([data_df['DX'+str(j)] for j in range(2, 31)])

# %%
DX_freq = DX_series.value_counts()

# %%
sum(DX_freq>200)/len(DX_freq)
# Out:
# 0.13131679043651512

# %%
len(DX_series.loc[DX_series.isin(DX_freq.loc[DX_freq>200].index)])/len(DX_series.dropna())
# Out:
# 0.9543447444167605

# %% [markdown]
# ## Prepare hyper-parameters and generate the .sh files

# %% [markdown]
# For embedding+NN with all codes:

# %%
# !rm hypertune*.sh

# %%
model_names = ['setsum']
code_embed_dims = [200]
fc_widths = [512]
md_widths = [128]
lr1s = [2e-4]
lr2s = [2e-5]
dropouts = [0.3]
batchsizes = [256]
penalties = [0.]
count_caps = [20]
tst_seeds = range(10)
cohorts = ['ami', 'chf', 'pna']
zips = [(embed_dim, tst_fold, cohort, 
         'all/sepdx1/test_embed/cosine/embed_mat_{0}_{1:.3f}_{2}_{3}{4}.npy'.format(embed_dim, penalty, count_cap, cohort, 
                                                                                    tst_fold)) 
        for embed_dim in code_embed_dims for penalty in penalties for count_cap in count_caps for cohort in cohorts 
        for tst_fold in tst_seeds] 
#zips = zips + [(embed_dim, tst_fold, '') for embed_dim in code_embed_dims for tst_fold in tst_seeds]
sep_dx1s = [1]
val_folds = [9]
result_files = ['output/ht_result1023_{}.csv']

# %%
para_itr = itertools.product(model_names, fc_widths, md_widths, lr1s, lr2s, dropouts, batchsizes, zips, sep_dx1s, 
                             val_folds, result_files)

para_lst = [(mo, z[0], fc, md, lr1, lr2, dr, ba, z[3], z[1], z[2], se, va, re) for mo, fc, md, lr1, lr2, dr, ba, z, se, va, re in para_itr]

# %%
len(para_lst)
# Out:
# 30

# %%
n_jobs = 8
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python train_template_all0827.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --tst_seed {9} --cohort {10} --sep_dx1 {11} --val_fold {12} --result_file {13} --job_index {14}\n'.format(*para, job_ind))

# %%
job_index = 5
for para in para_lst:
    with open('hypertune'+str(job_index)+'.sh', 'a') as f:
        f.write('python train_template_all0827.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --tst_seed {9} --cohort {10} --sep_dx1 {11} --val_fold {12} --result_file {13} --job_index {14}\n'.format(*para, job_index))

# %%
for p in [0, 1, 2, 5]:
    for cc in [20, 100, 500]:
        for f in range(10):
            os.rename(path+'all/sepdx1/embed_mat_200_{:.3f}_{}_{}.npy'.format(p, cc, f), path+'all/sepdx1/embed_mat_200_{:.3f}_{}_ami{}.npy'.format(p, cc, f))

# %% [markdown]
# For embedding+NN with a subset of codes:

# %%
# !rm hypertune*.sh

# %%
model_names = ['setsum_nn']
code_embed_dims = [200, 300]
fc_widths = [512, 1024]
md_widths = [128, 256]
lr1s = [2e-4]
lr2s = [2e-5]
dropouts = [0.3]
batchsizes = [256, 512]
embed_mats = ['pretrain']
penalties = [0, 0.5, 1.]
penalty_metrics = ['cosine']
count_caps = [0, 5, 20]
tst_seeds = range(10)
cohorts = ['ami']
DX_rarecutpoints = [20]
PR_rarecutpoints = [drp/2 for drp in DX_rarecutpoints]
val_folds = [5]
result_files = ['output/ht_result1001_{}.csv']

# %%
model_names = ['embed_sum', 'embed_pool']
code_embed_dims = [100]
fc_widths = [512]
md_widths = [128]
lr1s = [2e-4]
lr2s = [2e-5]
dropouts = [0.3]
batchsizes = [256]
embed_mats = ['random']
penalties = [0]
penalty_metrics = ['cosine']
count_caps = [5]
tst_seeds = range(10)
cohorts = ['ami']
DX_rarecutpoints = [20]
PR_rarecutpoints = [drp/2 for drp in DX_rarecutpoints]
val_folds = [5]
result_files = ['output/ht_result1001_{}.csv']

# %%
para_itr = itertools.product(model_names, code_embed_dims, fc_widths, md_widths, lr1s, lr2s, dropouts, batchsizes, embed_mats, 
                             penalties, penalty_metrics, count_caps, tst_seeds, cohorts, DX_rarecutpoints,
                             val_folds, result_files)
para_lst = [(mn, ced, fc, md, l1, l2, do, bs, em, p, pm, cc, ts, ch, dx, int(dx/2), vf, rf) 
            for mn, ced, fc, md, l1, l2, do, bs, em, p, pm, cc, ts, ch, dx, vf, rf in para_itr]

# %%
len(para_lst)
# Out:
# 720

# %%
n_jobs = 4
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python train_template_sub0922.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --penalty {9} --penalty_metric {10} --count_cap {11} --tst_seed {12} --cohort {13} --dx_rarecutpoint {14} --pr_rarecutpoint {15} --val_fold {16} --result_file {17} --job_index {18}\n'.format(*para, job_ind))

# %%
job_index = 5
for para in para_lst:
    with open('hypertune'+str(job_index)+'.sh', 'a') as f:
        f.write('python train_template_sub0922.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --penalty {9} --penalty_metric {10} --count_cap {11} --tst_seed {12} --cohort {13} --dx_rarecutpoint {14} --pr_rarecutpoint {15} --val_fold {16} --result_file {17} --job_index {18}\n'.format(*para, job_index))

# %% [markdown]
# Random search:

# %%
n_sample = 33

# %%
model_names = np.random.choice(['setsum_nn'], n_sample)
code_embed_dims = np.random.choice([200, 300], n_sample)
fc_widths = np.random.choice([512, 1024], n_sample)
md_widths = np.random.choice([128, 256], n_sample)
lr1s = np.random.choice([2e-4], n_sample)
lr2s = np.random.choice([2e-5], n_sample)
dropouts = np.random.choice([0.3], n_sample)
batchsizes = np.random.choice([256, 512], n_sample)
embed_mats = np.random.choice(['pretrain'], n_sample)
penalties = np.random.choice([0, 0.5, 1.], n_sample)
penalty_metrics = np.random.choice(['cosine'], n_sample)
count_caps = np.random.choice([0, 5, 20], n_sample)
cohorts = np.random.choice(['ami'], n_sample)
DX_rarecutpoints = np.random.choice([20], n_sample)
PR_rarecutpoints = [int(drp/2) for drp in DX_rarecutpoints]
val_folds = np.random.choice([5], n_sample)
result_files = ['output/ht_result1001_{}.csv']*n_sample

zips = zip(model_names, code_embed_dims, fc_widths, md_widths, lr1s, lr2s, dropouts, batchsizes, embed_mats, 
                             penalties, penalty_metrics, count_caps, cohorts, DX_rarecutpoints, PR_rarecutpoints,
                             val_folds, result_files)
tst_seeds = range(10)

# %%
para_itr = itertools.product(zips, tst_seeds)

para_lst = [(*z, t) for z, t in para_itr]

# %%
len(para_lst)
# Out:
# 330

# %%
n_jobs = 4
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python train_template_sub0922.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --penalty {9} --penalty_metric {10} --count_cap {11} --cohort {12} --dx_rarecutpoint {13} --pr_rarecutpoint {14} --val_fold {15} --result_file {16} --tst_seed {17} --job_index {18}\n'.format(*para, job_ind))

# %% [markdown]
# For OHE:

# %%
# !rm hypertune*.sh

# %%
fc_width1s = [1024]
fc_width2s = [256]
lrs = [1e-4]
dropouts = [0.3]
batchsizes = [512]
tst_seeds = range(10)
cohorts = ['ami', 'chf', 'pna']
val_folds = [5]
dx_rarecutpoints = [10]
pr_rarecutpoints = [10]
result_files = ['output/ht_result0925_{}.csv']

# %%
para_itr = itertools.product(fc_width1s, fc_width2s, lrs, dropouts, batchsizes, tst_seeds, cohorts, val_folds, 
                             dx_rarecutpoints, pr_rarecutpoints, result_files)

para_lst = list(para_itr)

# %%
len(para_lst)
# Out:
# 30

# %%
n_jobs = 1
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python train_template_ohe0925.py --fc_width1 {} --fc_width2 {} --lr {} --dropout {} --batchsize {} --tst_seed {} --cohort {} --val_fold {} --dx_rarecutpoint {} --pr_rarecutpoint {} --result_file {} --job_index {}\n'.format(*para, job_ind))

# %%
job_index = 5
for para in para_lst:
    with open('hypertune'+str(job_index)+'.sh', 'a') as f:
        f.write('python train_template_all0827.py --model_name {0} --code_embed_dim {1} --fc_width {2} --md_width {3} --lr1 {4} --lr2 {5} --dropout {6} --batchsize {7} --embed_file {8} --tst_seed {9} --cohort {10} --sep_dx1 {11} --val_fold {12} --result_file {13} --job_index {14}\n'.format(*para, job_index))

# %% [markdown]
# ## Result Analysis

# %% [markdown]
# ### Embedding + NN with all codes

# %%
res = pd.DataFrame()

# %%
for job_ind in range(8):
    df = pd.read_csv('output/ht_result1018_'+str(job_ind)+'.csv', 
                     names=['model_name', 'code_embed_dim', 'hosp_embed_dim', 'fc_width', 'md_width', 'lr1', 'lr2', 'dropout',
                            'batchsize', 'embed_file', 'cohort', 'sep_dx1', 'tst_seed', 'n_fold', 'auc_mean', 'auc_avg', 
                            'auc_freeze', 'y_pred_file'], index_col=None)
    res = pd.concat([res, df])

# %%
res = res.assign(cohort_seed=res.cohort+res.tst_seed.apply(lambda x:str(x)))

# %%
res = res.drop_duplicates(subset=['cohort_seed'], keep='last')

# %%
res
# Out:
#   model_name  code_embed_dim  hosp_embed_dim  fc_width  md_width     lr1  \
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 3     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 3     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 3     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 3     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 3     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
# 0     setsum             200               1       512       128  0.0002
# 1     setsum             200               1       512       128  0.0002
# 2     setsum             200               1       512       128  0.0002
#
#        lr2  dropout  batchsize  \
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 3  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 3  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 3  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 3  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 3  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
# 0  0.00002      0.3        256
# 1  0.00002      0.3        256
# 2  0.00002      0.3        256
#
#                                           embed_file cohort  sep_dx1  \
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 3  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 3  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 3  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 3  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 3  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
# 0  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    ami        1
# 1  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    chf        1
# 2  all/sepdx1/test_embed/cosine/embed_mat_200_0.0...    pna        1
#
#    tst_seed  n_fold  auc_mean  auc_avg  auc_freeze  \
# 0         0       9    0.7191   0.7210      0.7178
# 1         8       9    0.7278   0.7300      0.7272
# 2         6       9    0.6278   0.6304      0.6269
# 3         4       9    0.6761   0.6786      0.6755
# 0         1       9    0.7258   0.7279      0.7249
# 1         9       9    0.7267   0.7286      0.7256
# 2         7       9    0.6359   0.6389      0.6352
# 0         2       9    0.7165   0.7186      0.7158
# 1         0       9    0.6210   0.6236      0.6196
# 2         8       9    0.6365   0.6392      0.6356
# 3         6       9    0.6762   0.6785      0.6752
# 0         3       9    0.7194   0.7216      0.7186
# 1         1       9    0.6295   0.6325      0.6277
# 2         9       9    0.6296   0.6324      0.6284
# 3         7       9    0.6760   0.6784      0.6746
# 0         4       9    0.7228   0.7250      0.7218
# 1         2       9    0.6355   0.6387      0.6339
# 2         0       9    0.6746   0.6769      0.6737
# 3         8       9    0.6773   0.6798      0.6768
# 0         5       9    0.7150   0.7170      0.7143
# 1         3       9    0.6316   0.6342      0.6307
# 2         1       9    0.6815   0.6839      0.6802
# 3         9       9    0.6713   0.6739      0.6701
# 0         6       9    0.7117   0.7140      0.7110
# 1         4       9    0.6324   0.6351      0.6312
# 2         2       9    0.6757   0.6782      0.6744
# 0         7       9    0.7168   0.7187      0.7160
# 1         5       9    0.6297   0.6323      0.6284
# 2         3       9    0.6798   0.6824      0.6788
#
#                               y_pred_file
# 0  output/y_pred_mat18_10_19_01_37_46.npy
# 1  output/y_pred_mat18_10_19_02_54_20.npy
# 2  output/y_pred_mat18_10_19_04_47_49.npy
# 3  output/y_pred_mat18_10_19_06_48_49.npy
# 0  output/y_pred_mat18_10_19_02_36_17.npy
# 1  output/y_pred_mat18_10_19_04_05_00.npy
# 2  output/y_pred_mat18_10_19_06_25_44.npy
# 0  output/y_pred_mat18_10_19_01_37_49.npy
# 1  output/y_pred_mat18_10_19_03_29_59.npy
# 2  output/y_pred_mat18_10_19_05_23_08.npy
# 3  output/y_pred_mat18_10_19_07_24_09.npy
# 0  output/y_pred_mat18_10_19_01_39_06.npy
# 1  output/y_pred_mat18_10_19_03_34_49.npy
# 2  output/y_pred_mat18_10_19_05_34_12.npy
# 3  output/y_pred_mat18_10_19_07_40_49.npy
# 0  output/y_pred_mat18_10_19_01_36_05.npy
# 1  output/y_pred_mat18_10_19_03_28_36.npy
# 2  output/y_pred_mat18_10_19_05_36_34.npy
# 3  output/y_pred_mat18_10_19_07_35_37.npy
# 0  output/y_pred_mat18_10_19_01_36_08.npy
# 1  output/y_pred_mat18_10_19_03_29_09.npy
# 2  output/y_pred_mat18_10_19_05_34_04.npy
# 3  output/y_pred_mat18_10_19_07_35_59.npy
# 0  output/y_pred_mat18_10_19_01_37_06.npy
# 1  output/y_pred_mat18_10_19_03_30_53.npy
# 2  output/y_pred_mat18_10_19_05_34_01.npy
# 0  output/y_pred_mat18_10_19_01_24_58.npy
# 1  output/y_pred_mat18_10_19_03_21_14.npy
# 2  output/y_pred_mat18_10_19_05_21_51.npy

# %%
res.embed_file.apply(lambda x:x.split('/')[3]).head()
# Out:
# 0    cosine
# 1    cosine
# 2    cosine
# 3    cosine
# 4    cosine
# Name: embed_file, dtype: object

# %%
res = res.assign(penalty = res.embed_file.apply(lambda x:float(x.split('_')[4])))

# %%
res = res.assign(count_cap = res.embed_file.apply(lambda x:float(x.split('_')[5])))

# %%
res = res.assign(metric = res.embed_file.apply(lambda x:(x.split('/')[3])))

# %%
res = res.loc[res.penalty==0.5]

# %%
res_grouped = res.groupby(['cohort'])

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#        auc_freeze       auc_mean        auc_avg
#              mean count     mean count     mean count
# cohort
# ami       0.71930    10  0.72016    10  0.72224    10
# chf       0.62976    10  0.63095    10  0.63373    10
# pna       0.67476    10  0.67580    10  0.67822    10

# %%
for _, g in res_grouped:
    if g.auc_avg.mean() == res_grouped.auc_avg.mean().max():
        best = g

# %%
for n, g in res_grouped:
    print(n, 'freeze: {0:.4f} ({1:.4f})'.format(g.auc_freeze.mean(), g.auc_freeze.std()/np.sqrt(len(g))), 
         'mean: {0:.4f} ({1:.4f})'.format(g.auc_mean.mean(), g.auc_mean.std()/np.sqrt(len(g))), 
         'avg: {0:.4f} ({1:.4f})'.format(g.auc_avg.mean(), g.auc_avg.std()/np.sqrt(len(g))))
# Out:
# ami freeze: 0.7193 (0.0017) mean: 0.7202 (0.0017) avg: 0.7222 (0.0017)
# chf freeze: 0.6298 (0.0015) mean: 0.6309 (0.0015) avg: 0.6337 (0.0015)
# pna freeze: 0.6748 (0.0011) mean: 0.6758 (0.0011) avg: 0.6782 (0.0011)

# %%
res2 = pd.read_csv('output/ht_result0914.csv')

# %%
res2.loc[res2.tst_seed==0]
# Out:
#     model_name  code_embed_dim  hosp_embed_dim  fc_width  md_width     lr1  \
# 0       setsum             100               1       512       128  0.0002
# 5       setsum             100               1       512       128  0.0002
# 10      setsum             100               1       512       128  0.0002
# 15      setsum             200               1       512       128  0.0002
# 20      setsum             200               1       512       128  0.0002
# 25      setsum             200               1       512       128  0.0002
# 30      setsum             200               1       512       128  0.0002
# 73      setsum             100               1       512       128  0.0002
# 78      setsum             100               1       512       128  0.0002
# 83      setsum             100               1       512       128  0.0002
# 88      setsum             200               1       512       128  0.0002
# 93      setsum             200               1       512       128  0.0002
# 98      setsum             200               1       512       128  0.0002
# 103     setsum             200               1       512       128  0.0002
# 141     setsum             100               1       512       128  0.0002
# 146     setsum             100               1       512       128  0.0002
# 151     setsum             100               1       512       128  0.0002
# 156     setsum             200               1       512       128  0.0002
# 161     setsum             200               1       512       128  0.0002
# 166     setsum             200               1       512       128  0.0002
# 171     setsum             200               1       512       128  0.0002
#
#          lr2  dropout  batchsize                                   embed_file  \
# 0    0.00002      0.3        256   all/sepdx1/embed_mat_100_0.000_20_ami0.npy
# 5    0.00002      0.3        256   all/sepdx1/embed_mat_100_1.000_20_ami0.npy
# 10   0.00002      0.3        256   all/sepdx1/embed_mat_100_2.000_20_ami0.npy
# 15   0.00002      0.3        256   all/sepdx1/embed_mat_200_0.000_20_ami0.npy
# 20   0.00002      0.3        256   all/sepdx1/embed_mat_200_1.000_20_ami0.npy
# 25   0.00002      0.3        256   all/sepdx1/embed_mat_200_2.000_20_ami0.npy
# 30   0.00002      0.3        256   all/sepdx1/embed_mat_200_5.000_20_ami0.npy
# 73   0.00002      0.3        256  all/sepdx1/embed_mat_100_0.000_500_ami0.npy
# 78   0.00002      0.3        256  all/sepdx1/embed_mat_100_1.000_500_ami0.npy
# 83   0.00002      0.3        256  all/sepdx1/embed_mat_100_2.000_500_ami0.npy
# 88   0.00002      0.3        256  all/sepdx1/embed_mat_200_0.000_500_ami0.npy
# 93   0.00002      0.3        256  all/sepdx1/embed_mat_200_1.000_500_ami0.npy
# 98   0.00002      0.3        256  all/sepdx1/embed_mat_200_2.000_500_ami0.npy
# 103  0.00002      0.3        256  all/sepdx1/embed_mat_200_5.000_500_ami0.npy
# 141  0.00002      0.3        256  all/sepdx1/embed_mat_100_0.000_100_ami0.npy
# 146  0.00002      0.3        256  all/sepdx1/embed_mat_100_1.000_100_ami0.npy
# 151  0.00002      0.3        256  all/sepdx1/embed_mat_100_2.000_100_ami0.npy
# 156  0.00002      0.3        256  all/sepdx1/embed_mat_200_0.000_100_ami0.npy
# 161  0.00002      0.3        256  all/sepdx1/embed_mat_200_1.000_100_ami0.npy
# 166  0.00002      0.3        256  all/sepdx1/embed_mat_200_2.000_100_ami0.npy
# 171  0.00002      0.3        256  all/sepdx1/embed_mat_200_5.000_100_ami0.npy
#
#       ...   tst_seed  n_fold  auc_mean  auc_cil   auc_cih auc_avg auc_freeze  \
# 0     ...          0       7    0.7186  (0.7178   0.7194)  0.7212     0.7178
# 5     ...          0       7    0.7183  (0.7175   0.7191)  0.7208     0.7173
# 10    ...          0       7    0.7184  (0.7177   0.7190)  0.7209     0.7174
# 15    ...          0       7    0.7189  (0.7180   0.7197)  0.7210     0.7176
# 20    ...          0       7    0.7188  (0.7182   0.7194)  0.7211     0.7174
# 25    ...          0       7    0.7186  (0.7179   0.7194)  0.7208     0.7172
# 30    ...          0       7    0.7189  (0.7182   0.7196)  0.7211     0.7178
# 73    ...          0       7    0.7185  (0.7177   0.7194)  0.7208     0.7173
# 78    ...          0       7    0.7176  (0.7169   0.7183)  0.7202     0.7168
# 83    ...          0       7    0.7182  (0.7175   0.7188)  0.7209     0.7168
# 88    ...          0       7    0.7183  (0.7175   0.7191)  0.7206     0.7175
# 93    ...          0       7    0.7186  (0.7179   0.7193)  0.7206     0.7178
# 98    ...          0       7    0.7182  (0.7178   0.7186)  0.7205     0.7173
# 103   ...          0       7    0.7183  (0.7178   0.7187)  0.7203     0.7173
# 141   ...          0       7    0.7182  (0.7176   0.7188)  0.7207     0.7171
# 146   ...          0       7    0.7178  (0.7169   0.7186)  0.7204     0.7167
# 151   ...          0       7    0.7187  (0.7173   0.7201)  0.7212     0.7177
# 156   ...          0       7    0.7189  (0.7177   0.7202)  0.7211     0.7175
# 161   ...          0       7    0.7191  (0.7181   0.7200)  0.7214     0.7183
# 166   ...          0       7    0.7179  (0.7175   0.7184)  0.7201     0.7169
# 171   ...          0       7    0.7185  (0.7176   0.7193)  0.7206     0.7174
#
#                                 y_pred_file  count_cap penalty
# 0    output/y_pred_mat18_09_15_01_13_33.npy       20.0     0.0
# 5    output/y_pred_mat18_09_15_04_24_36.npy       20.0     1.0
# 10   output/y_pred_mat18_09_15_07_50_28.npy       20.0     2.0
# 15   output/y_pred_mat18_09_18_03_59_46.npy       20.0     0.0
# 20   output/y_pred_mat18_09_18_07_41_58.npy       20.0     1.0
# 25   output/y_pred_mat18_09_18_11_23_07.npy       20.0     2.0
# 30   output/y_pred_mat18_09_19_03_08_59.npy       20.0     5.0
# 73   output/y_pred_mat18_09_15_03_04_20.npy      500.0     0.0
# 78   output/y_pred_mat18_09_15_06_32_47.npy      500.0     1.0
# 83   output/y_pred_mat18_09_15_09_49_41.npy      500.0     2.0
# 88   output/y_pred_mat18_09_18_06_11_48.npy      500.0     0.0
# 93   output/y_pred_mat18_09_18_10_02_50.npy      500.0     1.0
# 98   output/y_pred_mat18_09_19_01_41_12.npy      500.0     2.0
# 103  output/y_pred_mat18_09_19_05_26_25.npy      500.0     5.0
# 141  output/y_pred_mat18_09_15_02_06_25.npy      100.0     0.0
# 146  output/y_pred_mat18_09_15_05_47_51.npy      100.0     1.0
# 151  output/y_pred_mat18_09_15_09_24_36.npy      100.0     2.0
# 156  output/y_pred_mat18_09_18_04_38_50.npy      100.0     0.0
# 161  output/y_pred_mat18_09_18_08_12_40.npy      100.0     1.0
# 166  output/y_pred_mat18_09_18_11_49_19.npy      100.0     2.0
# 171  output/y_pred_mat18_09_19_03_34_22.npy      100.0     5.0
#
# [21 rows x 22 columns]

# %%
res2.groupby(['code_embed_dim', 'penalty', 'fc_width', 'md_width'])[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#                                          auc_freeze        auc_mean        \
#                                                mean count      mean count
# code_embed_dim penalty fc_width md_width
# 100            0.0     128      128        0.719988     8  0.720675     8
#                0.5     128      128        0.719863     8  0.720538     8
# 200            0.0     128      128        0.719600    10  0.720200    10
#                                 256        0.719530    10  0.720130    10
#                        256      128        0.719420    10  0.720350    10
#                                 256        0.719730    10  0.720480    10
#                0.5     128      128        0.719610    10  0.720160    10
#                                 256        0.719120    10  0.719770    10
#                        256      128        0.719860    10  0.720620    10
#                                 256        0.719350    10  0.720150    10
# 300            0.0     128      128        0.719460    10  0.720100    10
#                                 256        0.719050    10  0.719760    10
#                        256      128        0.719650    10  0.720320    10
#                                 256        0.719500    10  0.720150    10
#                0.5     128      128        0.719310    10  0.719780    10
#                                 256        0.719010    10  0.719610    10
#                        256      128        0.719600    10  0.720440    10
#                                 256        0.719210    10  0.719920    10
#
#                                            auc_avg
#                                               mean count
# code_embed_dim penalty fc_width md_width
# 100            0.0     128      128       0.723075     8
#                0.5     128      128       0.722962     8
# 200            0.0     128      128       0.722390    10
#                                 256       0.722100    10
#                        256      128       0.722610    10
#                                 256       0.722380    10
#                0.5     128      128       0.722530    10
#                                 256       0.721770    10
#                        256      128       0.722820    10
#                                 256       0.722350    10
# 300            0.0     128      128       0.722270    10
#                                 256       0.721560    10
#                        256      128       0.722410    10
#                                 256       0.721960    10
#                0.5     128      128       0.722060    10
#                                 256       0.721730    10
#                        256      128       0.722590    10
#                                 256       0.721950    10

# %%
res.to_csv('output/ht_result1018embed_nn_0penalty_hosp30.csv', index=False)

# %%
res = pd.read_csv('output/ht_result1009penalty0.csv')

# %%
res = pd.concat([res, res2])

# %%
res.plot.scatter('penalty', 'auc_avg', xlim=(0, 1), ylim=(0.725, 0.733))

# %%
res = res.loc[res.md_width>100]

# %%
res.plot.scatter('fc_width', 'auc_mean', ylim=(0.71, 0.735))

# %%
res.plot.scatter('batchsize', 'auc_mean', ylim=(0.72, 0.73))

# %%
res.loc[res.auc_mean==res.auc_mean.max(), ['embed_file', 'y_pred_file', 'auc_mean']]
# Out:
#                   embed_file                             y_pred_file  auc_mean
# 5  all/embed_mat_pen6e-7.npy  output/y_pred_mat18_08_30_01_34_24.npy    0.7282
# 8  all/embed_mat_pen9e-7.npy  output/y_pred_mat18_08_30_03_43_48.npy    0.7282

# %%
res.loc[res.auc_mean>0.7285, ]
# Out:
#    model_name  code_embed_dim  hosp_embed_dim  fc_width  md_width     lr1  \
# 26     setsum             100               1       128       128  0.0002
# 35     setsum             100               1       128       256  0.0002
# 24     setsum             100               1       128       128  0.0002
# 34     setsum             100               1       128       256  0.0002
# 27     setsum             100               1       128       128  0.0002
#
#         lr2  dropout  batchsize                    embed_file  \
# 26  0.00002      0.1        128  all/embed_mat_pen_2_1e-6.npy
# 35  0.00005      0.3        256  all/embed_mat_pen_2_1e-6.npy
# 24  0.00001      0.1        256  all/embed_mat_pen_2_1e-6.npy
# 34  0.00005      0.1        256  all/embed_mat_pen_2_1e-6.npy
# 27  0.00002      0.5        256  all/embed_mat_pen_2_1e-6.npy
#
#                    data_file  sep_dx1  tst_seed  n_fold  auc_mean  auc_cil  \
# 26  cohorts/ami/ami_pred.csv        0         0       7    0.7286  (0.7275
# 35  cohorts/ami/ami_pred.csv        0         0       7    0.7286  (0.7278
# 24  cohorts/ami/ami_pred.csv        0         0       7    0.7287  (0.7275
# 34  cohorts/ami/ami_pred.csv        0         0       7    0.7286  (0.7271
# 27  cohorts/ami/ami_pred.csv        0         0       7    0.7286  (0.7278
#
#      auc_cih                             y_pred_file
# 26   0.7298)  output/y_pred_mat18_08_30_11_48_48.npy
# 35   0.7295)  output/y_pred_mat18_08_30_06_42_42.npy
# 24   0.7300)  output/y_pred_mat18_08_30_11_59_33.npy
# 34   0.7301)  output/y_pred_mat18_08_30_08_38_31.npy
# 27   0.7294)  output/y_pred_mat18_08_30_12_04_01.npy

# %% [markdown]
# ### Embedding + NN  with subset of codes

# %%
res = pd.DataFrame()

# %%
for job_ind in range(4):
    df = pd.read_csv('output/ht_result1001_'+str(job_ind)+'.csv', 
                     names=['model_name', 'code_embed_dim', 'hosp_embed_dim', 'fc_width', 'md_width', 'lr1', 'lr2', 'dropout',
                            'batchsize', 'embed_file', 'cohort', 'tst_seed', 'n_fold', 'penalty', 'penalty_metric', 'count_cap', 
                            'DX_rarecutpoint', 'PR_rarecutpoint', 'auc_mean', 'auc_avg', 'auc_freeze', 'y_pred_file'], index_col=None)
    res = pd.concat([res, df])

# %%
res = res.loc[res.model_name=='embed_sum']

# %%
res
# Out:
#     model_name  code_embed_dim  hosp_embed_dim  fc_width  md_width     lr1  \
# 50      setsum             100               1       512       128  0.0002
# 51      setsum             100               1       512       128  0.0002
# 52      setsum             100               1       512       128  0.0002
# 53      setsum             100               1       512       128  0.0002
# 54      setsum             100               1       512       128  0.0002
# 55      setsum             100               1       512       128  0.0002
# 56      setsum             100               1       512       128  0.0002
# 57      setsum             100               1       512       128  0.0002
# 58      setsum             100               1       512       128  0.0002
# 59      setsum             100               1       512       128  0.0002
# 60      setsum             100               1       512       128  0.0002
# 61      setsum             100               1       512       128  0.0002
# 62      setsum             100               1       512       128  0.0002
# 63      setsum             100               1       512       128  0.0002
# 64      setsum             100               1       512       128  0.0002
# 65      setsum             100               1       512       128  0.0002
# 66      setsum             100               1       512       128  0.0002
# 67      setsum             100               1       512       128  0.0002
# 68      setsum             100               1       512       128  0.0002
# 69      setsum             100               1       512       128  0.0002
# 70      setsum             100               1       512       128  0.0002
# 71      setsum             100               1       512       128  0.0002
# 72      setsum             100               1       512       128  0.0002
# 73      setsum             100               1       512       128  0.0002
# 74      setsum             100               1       512       128  0.0002
# 75      setsum             100               1       512       128  0.0002
# 76      setsum             100               1       512       128  0.0002
# 77      setsum             100               1       512       128  0.0002
# 78      setsum             100               1       512       128  0.0002
# 79      setsum             100               1       512       128  0.0002
# ..         ...             ...             ...       ...       ...     ...
# 83      setsum             100               1       512       128  0.0002
# 84      setsum             100               1       512       128  0.0002
# 85      setsum             100               1       512       128  0.0002
# 86      setsum             100               1       512       128  0.0002
# 87      setsum             100               1       512       128  0.0002
# 88      setsum             100               1       512       128  0.0002
# 89      setsum             100               1       512       128  0.0002
# 90      setsum             100               1       512       128  0.0002
# 91      setsum             100               1       512       128  0.0002
# 92      setsum             100               1       512       128  0.0002
# 93      setsum             100               1       512       128  0.0002
# 94      setsum             100               1       512       128  0.0002
# 95      setsum             100               1       512       128  0.0002
# 96      setsum             100               1       512       128  0.0002
# 97      setsum             100               1       512       128  0.0002
# 98      setsum             100               1       512       128  0.0002
# 99      setsum             100               1       512       128  0.0002
# 100     setsum             100               1       512       128  0.0002
# 101     setsum             100               1       512       128  0.0002
# 102     setsum             100               1       512       128  0.0002
# 103     setsum             100               1       512       128  0.0002
# 104     setsum             100               1       512       128  0.0002
# 105     setsum             100               1       512       128  0.0002
# 106     setsum             100               1       512       128  0.0002
# 107     setsum             100               1       512       128  0.0002
# 108     setsum             100               1       512       128  0.0002
# 109     setsum             100               1       512       128  0.0002
# 110     setsum             100               1       512       128  0.0002
# 111     setsum             100               1       512       128  0.0002
# 112     setsum             100               1       512       128  0.0002
#
#          lr2  dropout  batchsize embed_file  \
# 50   0.00002      0.3        256   pretrain
# 51   0.00002      0.3        256   pretrain
# 52   0.00002      0.3        256   pretrain
# 53   0.00002      0.3        256   pretrain
# 54   0.00002      0.3        256   pretrain
# 55   0.00002      0.3        256   pretrain
# 56   0.00002      0.3        256   pretrain
# 57   0.00002      0.3        256   pretrain
# 58   0.00002      0.3        256   pretrain
# 59   0.00002      0.3        256   pretrain
# 60   0.00002      0.3        256   pretrain
# 61   0.00002      0.3        256   pretrain
# 62   0.00002      0.3        256   pretrain
# 63   0.00002      0.3        256   pretrain
# 64   0.00002      0.3        256   pretrain
# 65   0.00002      0.3        256   pretrain
# 66   0.00002      0.3        256   pretrain
# 67   0.00002      0.3        256   pretrain
# 68   0.00002      0.3        256   pretrain
# 69   0.00002      0.3        256   pretrain
# 70   0.00002      0.3        256   pretrain
# 71   0.00002      0.3        256   pretrain
# 72   0.00002      0.3        256   pretrain
# 73   0.00002      0.3        256   pretrain
# 74   0.00002      0.3        256   pretrain
# 75   0.00002      0.3        256   pretrain
# 76   0.00002      0.3        256   pretrain
# 77   0.00002      0.3        256   pretrain
# 78   0.00002      0.3        256   pretrain
# 79   0.00002      0.3        256   pretrain
# ..       ...      ...        ...        ...
# 83   0.00002      0.3        256   pretrain
# 84   0.00002      0.3        256   pretrain
# 85   0.00002      0.3        256   pretrain
# 86   0.00002      0.3        256   pretrain
# 87   0.00002      0.3        256   pretrain
# 88   0.00002      0.3        256   pretrain
# 89   0.00002      0.3        256   pretrain
# 90   0.00002      0.3        256   pretrain
# 91   0.00002      0.3        256   pretrain
# 92   0.00002      0.3        256   pretrain
# 93   0.00002      0.3        256   pretrain
# 94   0.00002      0.3        256   pretrain
# 95   0.00002      0.3        256   pretrain
# 96   0.00002      0.3        256   pretrain
# 97   0.00002      0.3        256   pretrain
# 98   0.00002      0.3        256   pretrain
# 99   0.00002      0.3        256   pretrain
# 100  0.00002      0.3        256   pretrain
# 101  0.00002      0.3        256   pretrain
# 102  0.00002      0.3        256   pretrain
# 103  0.00002      0.3        256   pretrain
# 104  0.00002      0.3        256   pretrain
# 105  0.00002      0.3        256   pretrain
# 106  0.00002      0.3        256   pretrain
# 107  0.00002      0.3        256   pretrain
# 108  0.00002      0.3        256   pretrain
# 109  0.00002      0.3        256   pretrain
# 110  0.00002      0.3        256   pretrain
# 111  0.00002      0.3        256   pretrain
# 112  0.00002      0.3        256   pretrain
#
#                       ...                   n_fold  penalty  penalty_metric  \
# 50                    ...                        3      0.0          cosine
# 51                    ...                        3      0.0          cosine
# 52                    ...                        3      0.0          cosine
# 53                    ...                        3      0.0          cosine
# 54                    ...                        3      0.0          cosine
# 55                    ...                        3      0.0          cosine
# 56                    ...                        3      0.0          cosine
# 57                    ...                        3      0.0          cosine
# 58                    ...                        3      0.0          cosine
# 59                    ...                        3      0.0          cosine
# 60                    ...                        3      0.0          cosine
# 61                    ...                        3      0.0          cosine
# 62                    ...                        3      0.0          cosine
# 63                    ...                        3      0.0          cosine
# 64                    ...                        3      0.0          cosine
# 65                    ...                        3      0.0          cosine
# 66                    ...                        3      0.0          cosine
# 67                    ...                        3      0.0          cosine
# 68                    ...                        3      0.0          cosine
# 69                    ...                        3      0.0          cosine
# 70                    ...                        3      0.1          cosine
# 71                    ...                        3      0.1          cosine
# 72                    ...                        3      0.1          cosine
# 73                    ...                        3      0.1          cosine
# 74                    ...                        3      0.1          cosine
# 75                    ...                        3      0.1          cosine
# 76                    ...                        3      0.1          cosine
# 77                    ...                        3      0.1          cosine
# 78                    ...                        3      0.1          cosine
# 79                    ...                        3      0.1          cosine
# ..                    ...                      ...      ...             ...
# 83                    ...                        3      0.1          cosine
# 84                    ...                        3      0.1          cosine
# 85                    ...                        3      0.1          cosine
# 86                    ...                        3      0.1          cosine
# 87                    ...                        3      0.1          cosine
# 88                    ...                        3      0.1          cosine
# 89                    ...                        3      0.1          cosine
# 90                    ...                        3      0.1          cosine
# 91                    ...                        3      0.1          cosine
# 92                    ...                        3      0.1          cosine
# 93                    ...                        3      0.5          cosine
# 94                    ...                        3      0.5          cosine
# 95                    ...                        3      0.5          cosine
# 96                    ...                        3      0.5          cosine
# 97                    ...                        3      0.5          cosine
# 98                    ...                        3      0.5          cosine
# 99                    ...                        3      0.5          cosine
# 100                   ...                        3      0.5          cosine
# 101                   ...                        3      0.5          cosine
# 102                   ...                        3      0.5          cosine
# 103                   ...                        3      0.5          cosine
# 104                   ...                        3      0.5          cosine
# 105                   ...                        3      0.5          cosine
# 106                   ...                        3      0.5          cosine
# 107                   ...                        3      0.5          cosine
# 108                   ...                        3      0.5          cosine
# 109                   ...                        3      0.5          cosine
# 110                   ...                        3      0.5          cosine
# 111                   ...                        3      0.5          cosine
# 112                   ...                        3      0.5          cosine
#
#      count_cap DX_rarecutpoint  PR_rarecutpoint  auc_mean  auc_avg auc_freeze  \
# 50           5               0                0   0.71662  0.71973    0.71537
# 51           5              20               10   0.72133  0.72405    0.72053
# 52           5               0                0   0.71533  0.71807    0.71451
# 53           5              20               10   0.71732  0.72003    0.71653
# 54           5               0                0   0.70819  0.71097    0.70888
# 55           5              20               10   0.71253  0.71601    0.71210
# 56           5               0                0   0.72391  0.72719    0.72317
# 57         100              20               10   0.71727  0.72029    0.71656
# 58         100               0                0   0.71382  0.71589    0.71289
# 59         100              20               10   0.71548  0.71831    0.71516
# 60         100               0                0   0.71249  0.71507    0.71121
# 61         100              20               10   0.70911  0.71225    0.70890
# 62         100               0                0   0.72293  0.72582    0.72191
# 63         100              20               10   0.72260  0.72518    0.72247
# 64         500               0                0   0.72395  0.72690    0.72248
# 65         500              20               10   0.71472  0.71722    0.71402
# 66         500               0                0   0.71781  0.72052    0.71667
# 67         500              20               10   0.71161  0.71404    0.70985
# 68         500               0                0   0.71566  0.71841    0.71413
# 69         500              20               10   0.72254  0.72568    0.72188
# 70           5               0                0   0.71708  0.71991    0.71550
# 71           5              20               10   0.72375  0.72665    0.72234
# 72           5               0                0   0.71460  0.71723    0.71430
# 73           5              20               10   0.71814  0.72053    0.71716
# 74           5               0                0   0.70761  0.71077    0.70793
# 75           5              20               10   0.71440  0.71717    0.71318
# 76           5               0                0   0.72443  0.72740    0.72432
# 77         100              20               10   0.71744  0.72067    0.71667
# 78         100               0                0   0.71410  0.71659    0.71329
# 79         100              20               10   0.71714  0.71950    0.71624
# ..         ...             ...              ...       ...      ...        ...
# 83         100              10                5   0.71156  0.71377    0.71033
# 84         100              50               25   0.71433  0.71665    0.71331
# 85         100              10                5   0.72395  0.72643    0.72310
# 86         500              50               25   0.71792  0.72046    0.71541
# 87         500              10                5   0.71371  0.71583    0.71261
# 88         500              50               25   0.71668  0.71890    0.71521
# 89         500              10                5   0.71220  0.71466    0.71099
# 90         500              50               25   0.71073  0.71307    0.71045
# 91         500              10                5   0.72420  0.72667    0.72174
# 92         500              50               25   0.72447  0.72740    0.72405
# 93           5              10                5   0.72360  0.72620    0.72271
# 94           5              50               25   0.71322  0.71598    0.71295
# 95           5              10                5   0.71698  0.71996    0.71654
# 96           5              50               25   0.71235  0.71506    0.71095
# 97           5              10                5   0.71498  0.71737    0.71369
# 98           5              50               25   0.72450  0.72696    0.72333
# 99         100              10                5   0.71894  0.72147    0.71575
# 100        100              50               25   0.72237  0.72496    0.72116
# 101        100              10                5   0.71719  0.71935    0.71462
# 102        100              50               25   0.71581  0.71858    0.71423
# 103        100              10                5   0.71010  0.71271    0.70910
# 104        100              50               25   0.71485  0.71712    0.71330
# 105        100              10                5   0.72461  0.72720    0.72442
# 106        500              50               25   0.71738  0.71978    0.71436
# 107        500              10                5   0.71260  0.71523    0.71020
# 108        500              50               25   0.71461  0.71733    0.71238
# 109        500              10                5   0.71142  0.71391    0.70944
# 110        500              50               25   0.70937  0.71181    0.70668
# 111        500              10                5   0.72204  0.72477    0.71866
# 112        500              50               25   0.72256  0.72557    0.72155
#
#                                 y_pred_file
# 50   output/y_pred_mat18_09_29_07_13_13.npy
# 51   output/y_pred_mat18_09_29_07_34_07.npy
# 52   output/y_pred_mat18_09_29_07_54_09.npy
# 53   output/y_pred_mat18_09_29_08_14_00.npy
# 54   output/y_pred_mat18_09_29_08_35_48.npy
# 55   output/y_pred_mat18_09_29_08_56_02.npy
# 56   output/y_pred_mat18_09_29_09_18_05.npy
# 57   output/y_pred_mat18_09_29_09_40_41.npy
# 58   output/y_pred_mat18_09_29_10_01_22.npy
# 59   output/y_pred_mat18_09_29_10_21_35.npy
# 60   output/y_pred_mat18_09_29_10_43_10.npy
# 61   output/y_pred_mat18_09_29_11_05_17.npy
# 62   output/y_pred_mat18_09_29_11_24_02.npy
# 63   output/y_pred_mat18_09_29_11_46_56.npy
# 64   output/y_pred_mat18_09_30_12_09_47.npy
# 65   output/y_pred_mat18_09_30_12_30_36.npy
# 66   output/y_pred_mat18_09_30_12_49_48.npy
# 67   output/y_pred_mat18_09_30_01_10_15.npy
# 68   output/y_pred_mat18_09_30_01_30_46.npy
# 69   output/y_pred_mat18_09_30_01_52_00.npy
# 70   output/y_pred_mat18_09_30_02_14_36.npy
# 71   output/y_pred_mat18_09_30_02_35_03.npy
# 72   output/y_pred_mat18_09_30_02_57_59.npy
# 73   output/y_pred_mat18_09_30_03_19_39.npy
# 74   output/y_pred_mat18_09_30_03_41_34.npy
# 75   output/y_pred_mat18_09_30_04_05_03.npy
# 76   output/y_pred_mat18_09_30_04_28_22.npy
# 77   output/y_pred_mat18_09_30_04_49_06.npy
# 78   output/y_pred_mat18_09_30_05_10_41.npy
# 79   output/y_pred_mat18_09_30_05_32_34.npy
# ..                                      ...
# 83   output/y_pred_mat18_09_30_05_55_51.npy
# 84   output/y_pred_mat18_09_30_06_15_36.npy
# 85   output/y_pred_mat18_09_30_06_38_49.npy
# 86   output/y_pred_mat18_09_30_06_58_58.npy
# 87   output/y_pred_mat18_09_30_07_20_24.npy
# 88   output/y_pred_mat18_09_30_07_40_56.npy
# 89   output/y_pred_mat18_09_30_08_02_35.npy
# 90   output/y_pred_mat18_09_30_08_24_42.npy
# 91   output/y_pred_mat18_09_30_08_47_02.npy
# 92   output/y_pred_mat18_09_30_09_07_21.npy
# 93   output/y_pred_mat18_09_30_09_28_18.npy
# 94   output/y_pred_mat18_09_30_09_50_37.npy
# 95   output/y_pred_mat18_09_30_10_13_03.npy
# 96   output/y_pred_mat18_09_30_10_36_15.npy
# 97   output/y_pred_mat18_09_30_10_57_59.npy
# 98   output/y_pred_mat18_09_30_11_18_59.npy
# 99   output/y_pred_mat18_09_30_11_38_13.npy
# 100  output/y_pred_mat18_09_30_11_59_33.npy
# 101  output/y_pred_mat18_09_30_12_21_04.npy
# 102  output/y_pred_mat18_09_30_12_43_54.npy
# 103  output/y_pred_mat18_09_30_01_06_18.npy
# 104  output/y_pred_mat18_09_30_01_28_55.npy
# 105  output/y_pred_mat18_09_30_01_51_12.npy
# 106  output/y_pred_mat18_09_30_02_12_56.npy
# 107  output/y_pred_mat18_09_30_02_34_18.npy
# 108  output/y_pred_mat18_09_30_02_57_12.npy
# 109  output/y_pred_mat18_09_30_03_19_37.npy
# 110  output/y_pred_mat18_09_30_03_41_20.npy
# 111  output/y_pred_mat18_09_30_04_01_05.npy
# 112  output/y_pred_mat18_09_30_04_23_13.npy
#
# [360 rows x 22 columns]

# %%
res_grouped = res.groupby(['code_embed_dim', 'fc_width', 'md_width', 'penalty', 'batchsize', 'count_cap'])

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#                                                              auc_freeze        \
#                                                                    mean count
# code_embed_dim fc_width md_width penalty batchsize count_cap
# 200            512      128      0.0     256       20          0.716274    20
#                                          512       0           0.716043    20
#                                  1.0     256       5           0.718120    10
#                                                    20          0.717375    10
#                         256      0.0     256       5           0.716623    10
#                                  0.5     256       20          0.718081    10
#                                  1.0     512       0           0.717750    10
#                1024     128      0.0     256       5           0.716075    20
#                                                    20          0.716289    10
#                                          512       5           0.716510    10
#                         256      0.5     256       0           0.717100    10
#                                                    5           0.717737    10
#                                          512       0           0.717211    10
#                                  1.0     256       5           0.718093    10
# 300            512      128      0.5     256       5           0.717142    10
#                                          512       20          0.718084    10
#                                  1.0     512       5           0.718399    10
#                         256      0.5     512       20          0.718216    10
#                1024     128      0.5     512       0           0.716550    10
#                                                    5           0.716977    10
#                                                    20          0.718217    20
#                                  1.0     256       5           0.718012    10
#                                          512       5           0.718331    10
#                                                    20          0.718138    10
#                         256      0.0     512       0           0.715975    20
#                                  0.5     512       5           0.717075    10
#                                  1.0     256       5           0.718055    10
#                                                    20          0.717952    10
#
#                                                               auc_mean        \
#                                                                   mean count
# code_embed_dim fc_width md_width penalty batchsize count_cap
# 200            512      128      0.0     256       20         0.717040    20
#                                          512       0          0.716647    20
#                                  1.0     256       5          0.718895    10
#                                                    20         0.718833    10
#                         256      0.0     256       5          0.717226    10
#                                  0.5     256       20         0.718874    10
#                                  1.0     512       0          0.718174    10
#                1024     128      0.0     256       5          0.716861    20
#                                                    20         0.717320    10
#                                          512       5          0.717119    10
#                         256      0.5     256       0          0.717854    10
#                                                    5          0.718491    10
#                                          512       0          0.717859    10
#                                  1.0     256       5          0.719203    10
# 300            512      128      0.5     256       5          0.717836    10
#                                          512       20         0.718709    10
#                                  1.0     512       5          0.719031    10
#                         256      0.5     512       20         0.718833    10
#                1024     128      0.5     512       0          0.717316    10
#                                                    5          0.717761    10
#                                                    20         0.718905    20
#                                  1.0     256       5          0.719053    10
#                                          512       5          0.718952    10
#                                                    20         0.719122    10
#                         256      0.0     512       0          0.716324    20
#                                  0.5     512       5          0.717807    10
#                                  1.0     256       5          0.718965    10
#                                                    20         0.719124    10
#
#                                                                auc_avg
#                                                                   mean count
# code_embed_dim fc_width md_width penalty batchsize count_cap
# 200            512      128      0.0     256       20         0.719784    20
#                                          512       0          0.719599    20
#                                  1.0     256       5          0.720857    10
#                                                    20         0.720782    10
#                         256      0.0     256       5          0.719562    10
#                                  0.5     256       20         0.720653    10
#                                  1.0     512       0          0.720215    10
#                1024     128      0.0     256       5          0.719762    20
#                                                    20         0.719926    10
#                                          512       5          0.720019    10
#                         256      0.5     256       0          0.719863    10
#                                                    5          0.720403    10
#                                          512       0          0.720071    10
#                                  1.0     256       5          0.720972    10
# 300            512      128      0.5     256       5          0.719929    10
#                                          512       20         0.720655    10
#                                  1.0     512       5          0.720970    10
#                         256      0.5     512       20         0.720609    10
#                1024     128      0.5     512       0          0.719780    10
#                                                    5          0.719997    10
#                                                    20         0.720746    20
#                                  1.0     256       5          0.720847    10
#                                          512       5          0.720987    10
#                                                    20         0.720978    10
#                         256      0.0     512       0          0.718935    20
#                                  0.5     512       5          0.719765    10
#                                  1.0     256       5          0.720720    10
#                                                    20         0.720709    10

# %%
res.to_csv('output/ht_result1003embed_nn_sub.csv', index=False)

# %% [markdown]
# ### OHE models

# %%
res = pd.DataFrame()

# %%
for job_ind in range(1):
    df = pd.read_csv('output/ht_result0925_'+str(job_ind)+'.csv', 
                     names=['fc_width1', 'fc_width2', 'lr', 'dropout', 'batchsize', 'cohort', 'tst_seed', 'n_fold', 
                            'DX_rarecutpoint', 'PR_rarecutpoint', 'auc_mean', 'auc_avg', 'y_pred_file'], index_col=None)
    res = pd.concat([res, df])

# %%
res
# Out:
#     fc_width1  fc_width2      lr  dropout  batchsize cohort  tst_seed  n_fold  \
# 0        1024        256  0.0001      0.3        512    ami         0       5
# 1        1024        256  0.0001      0.3        512    chf         0       5
# 2        1024        256  0.0001      0.3        512    pna         0       5
# 3        1024        256  0.0001      0.3        512    ami         1       5
# 4        1024        256  0.0001      0.3        512    chf         1       5
# 5        1024        256  0.0001      0.3        512    pna         1       5
# 6        1024        256  0.0001      0.3        512    ami         2       5
# 7        1024        256  0.0001      0.3        512    chf         2       5
# 8        1024        256  0.0001      0.3        512    pna         2       5
# 9        1024        256  0.0001      0.3        512    ami         3       5
# 10       1024        256  0.0001      0.3        512    chf         3       5
# 11       1024        256  0.0001      0.3        512    pna         3       5
# 12       1024        256  0.0001      0.3        512    ami         4       5
# 13       1024        256  0.0001      0.3        512    chf         4       5
# 14       1024        256  0.0001      0.3        512    pna         4       5
# 15       1024        256  0.0001      0.3        512    ami         5       5
# 16       1024        256  0.0001      0.3        512    chf         5       5
# 17       1024        256  0.0001      0.3        512    pna         5       5
# 18       1024        256  0.0001      0.3        512    ami         6       5
# 19       1024        256  0.0001      0.3        512    chf         6       5
# 20       1024        256  0.0001      0.3        512    pna         6       5
# 21       1024        256  0.0001      0.3        512    ami         7       5
# 22       1024        256  0.0001      0.3        512    chf         7       5
# 23       1024        256  0.0001      0.3        512    pna         7       5
# 24       1024        256  0.0001      0.3        512    ami         8       5
# 25       1024        256  0.0001      0.3        512    chf         8       5
# 26       1024        256  0.0001      0.3        512    pna         8       5
# 27       1024        256  0.0001      0.3        512    ami         9       5
# 28       1024        256  0.0001      0.3        512    chf         9       5
# 29       1024        256  0.0001      0.3        512    pna         9       5
#
#     DX_rarecutpoint  PR_rarecutpoint  auc_mean  auc_avg  \
# 0                10               10   0.71339  0.71610
# 1                10               10   0.61783  0.62129
# 2                10               10   0.66755  0.67043
# 3                10               10   0.71938  0.72227
# 4                10               10   0.62258  0.62686
# 5                10               10   0.67248  0.67472
# 6                10               10   0.70725  0.71013
# 7                10               10   0.62727  0.63157
# 8                10               10   0.66761  0.67088
# 9                10               10   0.71382  0.71638
# 10               10               10   0.62566  0.62988
# 11               10               10   0.67220  0.67531
# 12               10               10   0.71510  0.71780
# 13               10               10   0.62636  0.62996
# 14               10               10   0.66816  0.67011
# 15               10               10   0.70978  0.71214
# 16               10               10   0.62471  0.62859
# 17               10               10   0.65954  0.66240
# 18               10               10   0.70653  0.70901
# 19               10               10   0.62151  0.62525
# 20               10               10   0.66753  0.66960
# 21               10               10   0.71184  0.71453
# 22               10               10   0.63224  0.63636
# 23               10               10   0.66699  0.66899
# 24               10               10   0.72035  0.72306
# 25               10               10   0.62885  0.63326
# 26               10               10   0.66799  0.67020
# 27               10               10   0.72035  0.72289
# 28               10               10   0.62468  0.62774
# 29               10               10   0.66460  0.66769
#
#                                y_pred_file
# 0   output/y_pred_mat18_09_26_12_37_55.npy
# 1   output/y_pred_mat18_09_26_12_50_49.npy
# 2   output/y_pred_mat18_09_26_01_14_10.npy
# 3   output/y_pred_mat18_09_26_01_20_51.npy
# 4   output/y_pred_mat18_09_26_01_34_06.npy
# 5   output/y_pred_mat18_09_26_01_56_41.npy
# 6   output/y_pred_mat18_09_26_02_03_15.npy
# 7   output/y_pred_mat18_09_26_02_16_32.npy
# 8   output/y_pred_mat18_09_26_02_39_27.npy
# 9   output/y_pred_mat18_09_26_02_46_03.npy
# 10  output/y_pred_mat18_09_26_02_59_21.npy
# 11  output/y_pred_mat18_09_26_03_22_40.npy
# 12  output/y_pred_mat18_09_26_03_28_53.npy
# 13  output/y_pred_mat18_09_26_03_42_05.npy
# 14  output/y_pred_mat18_09_26_04_06_08.npy
# 15  output/y_pred_mat18_09_26_04_12_34.npy
# 16  output/y_pred_mat18_09_26_04_25_45.npy
# 17  output/y_pred_mat18_09_26_04_49_25.npy
# 18  output/y_pred_mat18_09_26_04_55_33.npy
# 19  output/y_pred_mat18_09_26_05_08_13.npy
# 20  output/y_pred_mat18_09_26_05_32_26.npy
# 21  output/y_pred_mat18_09_26_05_38_54.npy
# 22  output/y_pred_mat18_09_26_05_52_02.npy
# 23  output/y_pred_mat18_09_26_06_14_59.npy
# 24  output/y_pred_mat18_09_26_06_21_31.npy
# 25  output/y_pred_mat18_09_26_06_34_15.npy
# 26  output/y_pred_mat18_09_26_06_56_48.npy
# 27  output/y_pred_mat18_09_26_07_03_12.npy
# 28  output/y_pred_mat18_09_26_07_15_49.npy
# 29  output/y_pred_mat18_09_26_07_38_37.npy

# %%
res_grouped = res.groupby(['cohort'])

# %%
res_grouped[['auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#         auc_mean         auc_avg
#             mean count      mean count
# cohort
# ami     0.713779    10  0.716431    10
# chf     0.625169    10  0.629076    10
# pna     0.667465    10  0.670033    10

# %%
for n, g in res_grouped:
    print(n, 'mean: {0:.4f} ({1:.4f})'.format(g.auc_mean.mean(), g.auc_mean.std()/np.sqrt(len(g))), 
         'avg: {0:.4f} ({1:.4f})'.format(g.auc_avg.mean(), g.auc_avg.std()/np.sqrt(len(g))))
# Out:
# ami mean: 0.7138 (0.0016) avg: 0.7164 (0.0016)
# chf mean: 0.6252 (0.0013) avg: 0.6291 (0.0013)
# pna mean: 0.6675 (0.0012) avg: 0.6700 (0.0011)
