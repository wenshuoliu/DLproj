# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import os, sys
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import statsmodels.stats.api as sms

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
path = '/nfs/turbo/umms-awaljee/wsliu/Data/NRD/'

# %%
module_path = '/home/wsliu/Codes/DLproj'
if module_path not in sys.path:
    sys.path.append(module_path)
if module_path+'/NRD' not in sys.path:
    sys.path.append(module_path+'/NRD')

# %%
from ccs_tools import core_dtypes_pd
from utils import preprocess
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Editing pbs Files

# %%
# !rm batch_gpu*.pbs

# %%
for job_index in range(12):
    with open('batch_gpu{}.pbs'.format(job_index), 'w') as f:
        f.write("""#!/bin/sh

#### PBS preamble

#PBS -N NRD_hypertune{}

#PBS -M wsliu@umich.edu
#PBS -m abe

#PBS -A awaljee_fluxg

#PBS -q fluxg

#PBS -V
#PBS -l nodes=1:gpus={},mem={}gb,walltime={}:00:00
#PBS -j oe

#### End PBS preamble

#  Show list of CPUs you ran on, if you're running under PBS
if [ -n "$PBS_NODEFILE" ]; then cat $PBS_NODEFILE; fi

#  Change to the directory you submitted from
if [ -n "$PBS_O_WORKDIR" ]; then cd $PBS_O_WORKDIR; fi

#  Put your job commands here:
sh hypertune{}.sh""".format(job_index, '1', 7, 72, job_index))

# %% [markdown]
# ## Prepare hyper-parameters and generate the .sh files

# %% [markdown]
# For embedding+NN with a subset of codes:

# %%
# !rm hypertune*.sh

# %%
model_names = ['setsum_nn', 'setsum_deep2']
DX1_dims = [30]
DX_dims = [200]
PR_dims = [100]
fc_widths = [256, 512, 1024]
#md_widths = [128]
lr1s = [2e-4]
lr2s = [2e-5]
dropouts = [0.3]
batchsizes = [256, 512, 1024]
embed_files = ['pretrain']
#penalties = [0]
#penalty_metrics = ['cosine']
count_caps = [20, 100, 200]
tst_seeds = [0]
cohorts = ['ami']
DX_rarecutpoints = [10, 90, 180, 270]
PR_rarecutpoints = [10, 90, 180, 270]
val_folds = [7]
other_preds = [0, 1]
ndxprs = [0]
result_files = ['output/ht_result1224_{}.csv']

# %% [markdown]
# For embedding+NN with all codes:

# %%
model_names = ['setsum_nn']
DX1_dims = [50, 100, 200]
DX_dims = [100, 200]
PR_dims = [50, 100]
fc_widths = [256, 512]
#md_widths = [128]
lr1s = [2e-4]
lr2s = [1e-5, 2e-5]
dropouts = [0.3]
batchsizes = [512]
embed_files = ['pretrain']
penalties = [0., 0.5, 1.]
penalty_metrics = ['cosine', 'l2']
count_caps = [5, 20, 100]
tst_seeds = [0]
cohorts = ['ami']
DX1_rarecutpoints = [10]
DX_rarecutpoints = [10]
PR_rarecutpoints = DX_rarecutpoints
val_folds = [7]
other_preds = [0]
ndxprs = [0]
result_files = ['output/ht_result0216_{}.csv']

# %%
para_itr = itertools.product(model_names, DX1_dims, DX_dims, PR_dims, fc_widths, lr1s, lr2s, dropouts, batchsizes, embed_files, 
                             count_caps, tst_seeds, cohorts, DX_rarecutpoints, other_preds, ndxprs, val_folds, 
                             result_files)
para_lst = [(mn, dx1d, dxd, prd, fc, l1, l2, do, bs, em, cc, ts, ch, dxr, dxr, op, ndp, vf, rf) 
            for mn, dx1d, dxd, prd, fc, l1, l2, do, bs, em, cc, ts, ch, dxr, op, ndp, vf, rf in para_itr]

# %%
para_itr = itertools.product(model_names, DX1_dims, DX_dims, PR_dims, fc_widths, lr1s, lr2s, dropouts, batchsizes, embed_files, 
                             count_caps, tst_seeds, cohorts, DX_rarecutpoints, PR_rarecutpoints, other_preds, ndxprs, val_folds, 
                             result_files)
para_lst = list(para_itr)

# %%
para_itr = itertools.product(model_names, DX1_dims, DX_dims, PR_dims, fc_widths, lr1s, lr2s, dropouts, batchsizes, embed_files, 
                             penalties, penalty_metrics, count_caps, tst_seeds, cohorts, DX1_rarecutpoints, DX_rarecutpoints, 
                             PR_rarecutpoints, other_preds, ndxprs, val_folds, result_files)
para_lst = list(para_itr)

# %%
len(para_lst)
# Out:
# 864

# %%
job_lst = range(12)
for para, job_ind in zip(para_lst, itertools.cycle(job_lst)):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python template_all_multispace0102.py --model_name {} --DX1_dim {} --DX_dim {} --PR_dim {} --fc_width {} --lr1 {} --lr2 {} --dropout {} --batchsize {} --embed_file {} --penalty {} --penalty_metric {} --count_cap {} --tst_seed {} --cohort {} --dx1_rarecutpoint {} --dx_rarecutpoint {} --pr_rarecutpoint {} --other_pred {} --ndxpr {} --val_fold {} --result_file {} --job_index {}\n'.format(*para, job_ind))

# %%
n_jobs = 10
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python template_all_multispace_notest.py --model_name {} --DX1_dim {} --DX_dim {} --PR_dim {} --fc_width {} --lr1 {} --lr2 {} --dropout {} --batchsize {} --embed_file {} --penalty {} --penalty_metric {} --count_cap {} --tst_seed {} --cohort {} --dx1_rarecutpoint {} --dx_rarecutpoint {} --pr_rarecutpoint {} --other_pred {} --ndxpr {} --val_fold {} --result_file {} --job_index {}\n'.format(*para, job_ind))

# %%
job_ind = 2
for para in para_lst:
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python template_all_multispace0102.py --model_name {} --DX1_dim {} --DX_dim {} --PR_dim {} --fc_width {} --lr1 {} --lr2 {} --dropout {} --batchsize {} --embed_file {} --penalty {} --penalty_metric {} --count_cap {} --tst_seed {} --cohort {} --dx1_rarecutpoint {} --dx_rarecutpoint {} --pr_rarecutpoint {} --other_pred {} --ndxpr {} --val_fold {} --result_file {} --job_index {}\n'.format(*para, job_ind))

# %% [markdown]
# Random search:

# %%
n_sample = 40

# %%
model_names = np.random.choice(['setsum_nn'], n_sample)
DX1_dims = np.random.choice([35], n_sample)
DX_dims = np.random.choice([200], n_sample)
PR_dims = np.random.choice([80], n_sample)
fc_widths = np.random.choice([450], n_sample)
#md_widths = np.random.choice([128, 256], n_sample)
lr1s = np.random.choice([2e-4], n_sample)
lr2s = np.random.choice([2e-5], n_sample)
dropouts = np.random.choice([0.3], n_sample)
batchsizes = np.random.choice([512], n_sample)
embed_files = np.random.choice(['pretrain'], n_sample)
#penalties = np.random.choice([0, 0.5, 1.], n_sample)
#penalty_metrics = np.random.choice(['cosine'], n_sample)
count_caps = np.random.choice([120], n_sample)
tst_seeds = np.random.choice([0], n_sample)
cohorts = np.random.choice(['ami'], n_sample)
DX_rarecutpoints = np.random.choice([10], n_sample)
PR_rarecutpoints = DX_rarecutpoints
val_folds = np.random.choice([5], n_sample)
other_preds = np.random.choice([0], n_sample)
ndxprs = np.random.choice([0], n_sample)
result_files = ['output/ht_result0101_{}.csv']*n_sample

# %%
zips = zip(model_names, DX1_dims, DX_dims, PR_dims, fc_widths, lr1s, lr2s, dropouts, batchsizes, embed_files, 
            count_caps, tst_seeds, cohorts, DX_rarecutpoints, PR_rarecutpoints, other_preds, ndxprs, val_folds, result_files)

# %%
para_lst = list(zips)

# %%
len(para_lst)
# Out:
# 40

# %%
n_jobs = 8
for para, job_ind in zip(para_lst, itertools.cycle(range(n_jobs))):
    with open('hypertune'+str(job_ind)+'.sh', 'a') as f:
        f.write('python template_sub_multispace1218.py --model_name {} --DX1_dim {} --DX_dim {} --PR_dim {} --fc_width {} --lr1 {} --lr2 {} --dropout {} --batchsize {} --embed_file {} --count_cap {} --tst_seed {} --cohort {} --dx_rarecutpoint {} --pr_rarecutpoint {} --other_pred {} --ndxpr {} --val_fold {} --result_file {} --job_index {}\n'.format(*para, job_ind))

# %% [markdown]
# ## Result Analysis

# %% [markdown]
# ### Embedding + NN  with subset of codes

# %%
res = pd.DataFrame()

# %%
for job_ind in range(12):
    df = pd.read_csv('output/ht_result1231_'+str(job_ind)+'.csv', 
                     names=['model_name', 'DX1_dim', 'DX_dim', 'PR_dim', 'hosp_embed_dim', 'fc_width', 'lr1', 'lr2', 'dropout',
                            'batchsize', 'embed_file', 'cohort', 'tst_seed', 'n_fold', 'count_cap', 
                            'DX_rarecutpoint', 'PR_rarecutpoint', 'other_pred', 'ndxpr', 'auc_mean', 'auc_avg', 'auc_freeze', 'y_pred_file'], index_col=None)
    res = pd.concat([res, df])

# %%
res.head()
# Out:
#   model_name  DX1_dim  DX_dim  PR_dim  hosp_embed_dim  fc_width     lr1  \
# 0  setsum_nn       30     200      80               1       256  0.0002
# 1  setsum_nn       35     200      80               1       512  0.0002
# 2  setsum_nn       35     200      80               1       256  0.0002
# 3  setsum_nn       30     200      80               1       512  0.0002
# 4  setsum_nn       35     200      80               1       256  0.0002
#
#        lr2  dropout  batchsize                   ...                   n_fold  \
# 0  0.00002      0.3        512                   ...                        5
# 1  0.00002      0.3        400                   ...                        5
# 2  0.00002      0.3        400                   ...                        5
# 3  0.00002      0.3        512                   ...                        5
# 4  0.00002      0.3        400                   ...                        5
#
#   count_cap  DX_rarecutpoint  PR_rarecutpoint  other_pred  ndxpr  auc_mean  \
# 0       200               10               10           0      0   0.71322
# 1       200              180              180           0      0   0.71357
# 2       200               10               10           0      0   0.71341
# 3       120               10               10           0      0   0.71352
# 4       120               10               10           0      0   0.71340
#
#    auc_avg  auc_freeze                             y_pred_file
# 0  0.71661     0.71294  output/y_pred_mat19_01_01_12_09_09.npy
# 1  0.71611     0.71263  output/y_pred_mat19_01_01_12_37_00.npy
# 2  0.71604     0.71260  output/y_pred_mat19_01_01_01_15_47.npy
# 3  0.71651     0.71263  output/y_pred_mat19_01_01_01_51_13.npy
# 4  0.71643     0.71255  output/y_pred_mat19_01_01_02_29_38.npy
#
# [5 rows x 23 columns]

# %%
res.shape
# Out:
# (600, 23)

# %%
res_grouped = res.loc[res.auc_freeze>0.7135].groupby(['model_name', 'DX1_dim', 'DX_dim', 'PR_dim', 'fc_width', 'count_cap', 
                                                     'batchsize', 'DX_rarecutpoint'])

# %%
res_grouped = res.groupby(['model_name', 'DX1_dim', 'DX_dim', 'PR_dim', 'fc_width', 'count_cap', 'batchsize', 'DX_rarecutpoint'])

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#                                                                               auc_freeze  \
#                                                                                     mean
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30                0.713550
#                                           200       512       30                0.714043
#                                  512      120       512       180               0.713530
#                                           200       512       30                0.713580
#                                                               180               0.713640
#            35      200    80     256      120       400       180               0.713940
#                                                     512       30                0.713785
#                                           200       400       180               0.713660
#                                  512      120       400       30                0.713660
#                                           200       400       30                0.714150
#                                                     512       10                0.713540
#                                                               180               0.713970
#
#                                                                                      \
#                                                                               count
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30                  1
#                                           200       512       30                  3
#                                  512      120       512       180                 1
#                                           200       512       30                  2
#                                                               180                 1
#            35      200    80     256      120       400       180                 1
#                                                     512       30                  2
#                                           200       400       180                 1
#                                  512      120       400       30                  2
#                                           200       400       30                  1
#                                                     512       10                  1
#                                                               180                 1
#
#                                                                                auc_mean  \
#                                                                                    mean
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30               0.714240
#                                           200       512       30               0.714643
#                                  512      120       512       180              0.713990
#                                           200       512       30               0.714210
#                                                               180              0.714190
#            35      200    80     256      120       400       180              0.714160
#                                                     512       30               0.714535
#                                           200       400       180              0.714350
#                                  512      120       400       30               0.714130
#                                           200       400       30               0.714600
#                                                     512       10               0.714160
#                                                               180              0.714100
#
#                                                                                      \
#                                                                               count
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30                  1
#                                           200       512       30                  3
#                                  512      120       512       180                 1
#                                           200       512       30                  2
#                                                               180                 1
#            35      200    80     256      120       400       180                 1
#                                                     512       30                  2
#                                           200       400       180                 1
#                                  512      120       400       30                  2
#                                           200       400       30                  1
#                                                     512       10                  1
#                                                               180                 1
#
#                                                                                 auc_avg  \
#                                                                                    mean
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30               0.717210
#                                           200       512       30               0.717460
#                                  512      120       512       180              0.716830
#                                           200       512       30               0.717350
#                                                               180              0.716890
#            35      200    80     256      120       400       180              0.716740
#                                                     512       30               0.717605
#                                           200       400       180              0.717130
#                                  512      120       400       30               0.717110
#                                           200       400       30               0.717960
#                                                     512       10               0.717360
#                                                               180              0.716970
#
#
#                                                                               count
# model_name DX1_dim DX_dim PR_dim fc_width count_cap batchsize DX_rarecutpoint
# setsum_nn  30      200    80     256      120       400       30                  1
#                                           200       512       30                  3
#                                  512      120       512       180                 1
#                                           200       512       30                  2
#                                                               180                 1
#            35      200    80     256      120       400       180                 1
#                                                     512       30                  2
#                                           200       400       180                 1
#                                  512      120       400       30                  2
#                                           200       400       30                  1
#                                                     512       10                  1
#                                                               180                 1

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count']).shape
# Out:
# (600, 6)

# %%
res.to_csv('output/ht_result1231.csv', index=False)

# %%
res.loc[(res.DX1_dim==35)&(res.DX_dim==200)&(res.PR_dim==80)&(res.count_cap==120)&(res.DX_rarecutpoint==10)&(res.batchsize==512)
       &(res.fc_width==450)]
# Out:
# Empty DataFrame
# Columns: [model_name, DX1_dim, DX_dim, PR_dim, hosp_embed_dim, fc_width, lr1, lr2, dropout, batchsize, embed_file, cohort, tst_seed, n_fold, count_cap, DX_rarecutpoint, PR_rarecutpoint, other_pred, ndxpr, auc_mean, auc_avg, auc_freeze, y_pred_file]
# Index: []
#
# [0 rows x 23 columns]

# %%
res = pd.read_csv('output/ht_result1227.csv')

# %%
res2 = pd.read_csv('output/ht_result1219.csv')

# %%
res2.loc[res2.auc_freeze>0.7135]
# Out:
#     model_name  DX1_dim  DX_dim  PR_dim  hosp_embed_dim  fc_width     lr1  \
# 106  setsum_nn       20     200     100               1       256  0.0002
# 165  setsum_nn       20     200     100               1       512  0.0002
# 167  setsum_nn       40     200     100               1       256  0.0002
# 170  setsum_nn       20     200     100               1       512  0.0002
# 209  setsum_nn       20     200     200               1       256  0.0002
# 217  setsum_nn       40     200     100               1       512  0.0002
#
#          lr2  dropout  batchsize                   ...                    \
# 106  0.00002      0.3        512                   ...
# 165  0.00002      0.3        512                   ...
# 167  0.00002      0.3        512                   ...
# 170  0.00002      0.3        512                   ...
# 209  0.00002      0.3        512                   ...
# 217  0.00002      0.3        512                   ...
#
#     tst_seed n_fold  count_cap  DX_rarecutpoint  PR_rarecutpoint  other_pred  \
# 106        0      7          1               10                5           0
# 165        0      7        100               10                5           0
# 167        0      7          5               10                5           0
# 170        0      7        100               10                5           0
# 209        0      7        100               10                5           0
# 217        0      7        100               10                5           0
#
#      auc_mean  auc_avg  auc_freeze                             y_pred_file
# 106   0.71390  0.71700     0.71365  output/y_pred_mat18_12_20_11_23_06.npy
# 165   0.71388  0.71674     0.71368  output/y_pred_mat18_12_19_11_12_36.npy
# 167   0.71465  0.71788     0.71376  output/y_pred_mat18_12_20_12_58_32.npy
# 170   0.71478  0.71784     0.71381  output/y_pred_mat18_12_20_10_29_21.npy
# 209   0.71434  0.71707     0.71374  output/y_pred_mat18_12_20_11_37_02.npy
# 217   0.71418  0.71714     0.71358  output/y_pred_mat18_12_20_01_09_19.npy
#
# [6 rows x 22 columns]

# %% [markdown]
# ### Embedding + NN  with all codes

# %%
res = pd.DataFrame()

# %%
for job_ind in range(1, 12):
    df = pd.read_csv('output/ht_result0215_'+str(job_ind)+'.csv', 
                     names=['model_name', 'DX1_dim', 'DX_dim', 'PR_dim', 'hosp_embed_dim', 'fc_width', 'lr1', 'lr2', 'dropout',
                            'batchsize', 'embed_file', 'cohort', 'tst_seed', 'n_fold', 'penalty', 'penalty_metric', 'count_cap', 
                            'DX1_rarecutpoint', 'DX_rarecutpoint', 'PR_rarecutpoint', 'other_pred', 'ndxpr', 'auc_mean', 'auc_avg', 
                            'auc_freeze', 'y_pred_file'], index_col=None)
    res = pd.concat([res, df])

# %%
res.head()
# Out:
#   model_name  DX1_dim  DX_dim  PR_dim  hosp_embed_dim  fc_width     lr1  \
# 0  setsum_nn      200     200     100               1       512  0.0002
# 1  setsum_nn      200     200     100               1       512  0.0002
# 2  setsum_nn      200     200     100               1       512  0.0002
# 3  setsum_nn      200     200     100               1       512  0.0002
# 4  setsum_nn      200     200     100               1       512  0.0002
#
#        lr2  dropout  batchsize  \
# 0  0.00002      0.3        512
# 1  0.00002      0.3        512
# 2  0.00002      0.3        512
# 3  0.00002      0.3        512
# 4  0.00002      0.3        512
#
#                          ...                         count_cap  \
# 0                        ...                                 5
# 1                        ...                                 5
# 2                        ...                                 5
# 3                        ...                                20
# 4                        ...                                20
#
#   DX1_rarecutpoint  DX_rarecutpoint  PR_rarecutpoint  other_pred ndxpr  \
# 0               10               10               10           0     0
# 1               10               10               10           0     0
# 2               10               10               10           0     0
# 3               10               10               10           0     0
# 4               10               10               10           0     0
#
#    auc_mean  auc_avg  auc_freeze  \
# 0   0.67790  0.68192     0.67849
# 1   0.64857  0.65267     0.64730
# 2   0.61723  0.62120     0.61571
# 3   0.67941  0.68304     0.67901
# 4   0.64520  0.64879     0.64450
#
#                                          y_pred_file
# 0  /nfs/turbo/umms-awaljee/wsliu/Data/NRD/y_pred_...
# 1  /nfs/turbo/umms-awaljee/wsliu/Data/NRD/y_pred_...
# 2  /nfs/turbo/umms-awaljee/wsliu/Data/NRD/y_pred_...
# 3  /nfs/turbo/umms-awaljee/wsliu/Data/NRD/y_pred_...
# 4  /nfs/turbo/umms-awaljee/wsliu/Data/NRD/y_pred_...
#
# [5 rows x 26 columns]

# %%
res.shape
# Out:
# (120, 26)

# %%
res = pd.read_csv('output/ht_result1227.csv')

# %%
res.groupby(['DX1_dim', 'DX_dim', 'PR_dim',
       'fc_width', 'batchsize',
        'count_cap', 'DX_rarecutpoint',
       'PR_rarecutpoint']).agg(['mean', 'count'])
# Out:
#                                                                                    hosp_embed_dim  \
#                                                                                              mean
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                           1
#                       500      256       30        30              30                           1
#                                320       150       180             180                          1
#                90     450      512       180       100             100                          1
#                       500      320       150       50              50                           1
#                       512      320       30        180             180                          1
#                       530      320       30        100             100                          1
#                100    470      400       240       50              50                           1
#                110    530      256       120       150             150                          1
#                120    470      256       200       50              50                           1
#                       520      320       180       180             180                          1
#                130    520      512       10        180             180                          1
#                       530      400       100       100             100                          1
#         190    80     480      320       300       150             150                          1
#                90     450      400       10        120             120                          1
#                                512       300       10              10                           1
#                       490      320       100       100             100                          1
#                       540      256       80        10              10                           1
#                100    450      320       150       10              10                           1
#                       470      320       240       100             100                          1
#                       512      256       120       10              10                           1
#                                512       30        70              70                           1
#                       530      256       80        120             120                          1
#                       550      400       200       10              10                           1
#                110    480      400       100       120             120                          1
#                       540      400       10        100             100                          1
#                120    450      256       150       100             100                          1
#                       460      256       120       180             180                          1
#                       480      512       50        180             180                          1
#                       490      320       120       150             150                          1
# ...                                                                                           ...
# 50      230    100    490      320       200       50              50                           1
#                       550      256       120       120             120                          1
#                110    450      320       200       70              70                           1
#                       490      512       100       70              70                           1
#                       512      512       120       180             180                          1
#                       520      256       30        100             100                          1
#                                400       200       70              70                           1
#                       530      512       300       180             180                          1
#                130    460      256       180       120             120                          1
#                                400       50        120             120                          1
#                       480      400       150       50              50                           1
#                       550      400       100       70              70                           1
#         240    80     470      320       180       100             100                          1
#                       500      256       150       180             180                          1
#                       530      512       300       150             150                          1
#                       540      400       50        30              30                           1
#                100    460      320       120       150             150                          1
#                       490      512       150       30              30                           1
#                       500      512       80        180             180                          1
#                       530      400       300       10              10                           1
#                       550      256       30        100             100                          1
#                                          150       150             150                          1
#                                512       240       50              50                           1
#                120    470      256       200       100             100                          1
#                130    450      320       180       100             100                          1
#                       480      256       150       120             120                          1
#                       490      512       200       30              30                           1
#                       500      256       100       100             100                          1
#                       512      512       240       100             100                          1
#                       520      400       100       10              10                           1
#
#                                                                                           \
#                                                                                    count
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  1
#                       500      256       30        30              30                  1
#                                320       150       180             180                 1
#                90     450      512       180       100             100                 1
#                       500      320       150       50              50                  1
#                       512      320       30        180             180                 1
#                       530      320       30        100             100                 1
#                100    470      400       240       50              50                  1
#                110    530      256       120       150             150                 1
#                120    470      256       200       50              50                  1
#                       520      320       180       180             180                 1
#                130    520      512       10        180             180                 1
#                       530      400       100       100             100                 1
#         190    80     480      320       300       150             150                 1
#                90     450      400       10        120             120                 1
#                                512       300       10              10                  1
#                       490      320       100       100             100                 1
#                       540      256       80        10              10                  1
#                100    450      320       150       10              10                  1
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
#                       512      512       240       100             100                 1
#                       520      400       100       10              10                  1
#
#                                                                                        lr1  \
#                                                                                       mean
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70               0.0002
#                       500      256       30        30              30               0.0002
#                                320       150       180             180              0.0002
#                90     450      512       180       100             100              0.0002
#                       500      320       150       50              50               0.0002
#                       512      320       30        180             180              0.0002
#                       530      320       30        100             100              0.0002
#                100    470      400       240       50              50               0.0002
#                110    530      256       120       150             150              0.0002
#                120    470      256       200       50              50               0.0002
#                       520      320       180       180             180              0.0002
#                130    520      512       10        180             180              0.0002
#                       530      400       100       100             100              0.0002
#         190    80     480      320       300       150             150              0.0002
#                90     450      400       10        120             120              0.0002
#                                512       300       10              10               0.0002
#                       490      320       100       100             100              0.0002
#                       540      256       80        10              10               0.0002
#                100    450      320       150       10              10               0.0002
#                       470      320       240       100             100              0.0002
#                       512      256       120       10              10               0.0002
#                                512       30        70              70               0.0002
#                       530      256       80        120             120              0.0002
#                       550      400       200       10              10               0.0002
#                110    480      400       100       120             120              0.0002
#                       540      400       10        100             100              0.0002
#                120    450      256       150       100             100              0.0002
#                       460      256       120       180             180              0.0002
#                       480      512       50        180             180              0.0002
#                       490      320       120       150             150              0.0002
# ...                                                                                    ...
# 50      230    100    490      320       200       50              50               0.0002
#                       550      256       120       120             120              0.0002
#                110    450      320       200       70              70               0.0002
#                       490      512       100       70              70               0.0002
#                       512      512       120       180             180              0.0002
#                       520      256       30        100             100              0.0002
#                                400       200       70              70               0.0002
#                       530      512       300       180             180              0.0002
#                130    460      256       180       120             120              0.0002
#                                400       50        120             120              0.0002
#                       480      400       150       50              50               0.0002
#                       550      400       100       70              70               0.0002
#         240    80     470      320       180       100             100              0.0002
#                       500      256       150       180             180              0.0002
#                       530      512       300       150             150              0.0002
#                       540      400       50        30              30               0.0002
#                100    460      320       120       150             150              0.0002
#                       490      512       150       30              30               0.0002
#                       500      512       80        180             180              0.0002
#                       530      400       300       10              10               0.0002
#                       550      256       30        100             100              0.0002
#                                          150       150             150              0.0002
#                                512       240       50              50               0.0002
#                120    470      256       200       100             100              0.0002
#                130    450      320       180       100             100              0.0002
#                       480      256       150       120             120              0.0002
#                       490      512       200       30              30               0.0002
#                       500      256       100       100             100              0.0002
#                       512      512       240       100             100              0.0002
#                       520      400       100       10              10               0.0002
#
#                                                                                           \
#                                                                                    count
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  1
#                       500      256       30        30              30                  1
#                                320       150       180             180                 1
#                90     450      512       180       100             100                 1
#                       500      320       150       50              50                  1
#                       512      320       30        180             180                 1
#                       530      320       30        100             100                 1
#                100    470      400       240       50              50                  1
#                110    530      256       120       150             150                 1
#                120    470      256       200       50              50                  1
#                       520      320       180       180             180                 1
#                130    520      512       10        180             180                 1
#                       530      400       100       100             100                 1
#         190    80     480      320       300       150             150                 1
#                90     450      400       10        120             120                 1
#                                512       300       10              10                  1
#                       490      320       100       100             100                 1
#                       540      256       80        10              10                  1
#                100    450      320       150       10              10                  1
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
#                       512      512       240       100             100                 1
#                       520      400       100       10              10                  1
#
#                                                                                         lr2  \
#                                                                                        mean
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70               0.00002
#                       500      256       30        30              30               0.00002
#                                320       150       180             180              0.00002
#                90     450      512       180       100             100              0.00002
#                       500      320       150       50              50               0.00002
#                       512      320       30        180             180              0.00002
#                       530      320       30        100             100              0.00002
#                100    470      400       240       50              50               0.00002
#                110    530      256       120       150             150              0.00002
#                120    470      256       200       50              50               0.00002
#                       520      320       180       180             180              0.00002
#                130    520      512       10        180             180              0.00002
#                       530      400       100       100             100              0.00002
#         190    80     480      320       300       150             150              0.00002
#                90     450      400       10        120             120              0.00002
#                                512       300       10              10               0.00002
#                       490      320       100       100             100              0.00002
#                       540      256       80        10              10               0.00002
#                100    450      320       150       10              10               0.00002
#                       470      320       240       100             100              0.00002
#                       512      256       120       10              10               0.00002
#                                512       30        70              70               0.00002
#                       530      256       80        120             120              0.00002
#                       550      400       200       10              10               0.00002
#                110    480      400       100       120             120              0.00002
#                       540      400       10        100             100              0.00002
#                120    450      256       150       100             100              0.00002
#                       460      256       120       180             180              0.00002
#                       480      512       50        180             180              0.00002
#                       490      320       120       150             150              0.00002
# ...                                                                                     ...
# 50      230    100    490      320       200       50              50               0.00002
#                       550      256       120       120             120              0.00002
#                110    450      320       200       70              70               0.00002
#                       490      512       100       70              70               0.00002
#                       512      512       120       180             180              0.00002
#                       520      256       30        100             100              0.00002
#                                400       200       70              70               0.00002
#                       530      512       300       180             180              0.00002
#                130    460      256       180       120             120              0.00002
#                                400       50        120             120              0.00002
#                       480      400       150       50              50               0.00002
#                       550      400       100       70              70               0.00002
#         240    80     470      320       180       100             100              0.00002
#                       500      256       150       180             180              0.00002
#                       530      512       300       150             150              0.00002
#                       540      400       50        30              30               0.00002
#                100    460      320       120       150             150              0.00002
#                       490      512       150       30              30               0.00002
#                       500      512       80        180             180              0.00002
#                       530      400       300       10              10               0.00002
#                       550      256       30        100             100              0.00002
#                                          150       150             150              0.00002
#                                512       240       50              50               0.00002
#                120    470      256       200       100             100              0.00002
#                130    450      320       180       100             100              0.00002
#                       480      256       150       120             120              0.00002
#                       490      512       200       30              30               0.00002
#                       500      256       100       100             100              0.00002
#                       512      512       240       100             100              0.00002
#                       520      400       100       10              10               0.00002
#
#                                                                                           \
#                                                                                    count
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  1
#                       500      256       30        30              30                  1
#                                320       150       180             180                 1
#                90     450      512       180       100             100                 1
#                       500      320       150       50              50                  1
#                       512      320       30        180             180                 1
#                       530      320       30        100             100                 1
#                100    470      400       240       50              50                  1
#                110    530      256       120       150             150                 1
#                120    470      256       200       50              50                  1
#                       520      320       180       180             180                 1
#                130    520      512       10        180             180                 1
#                       530      400       100       100             100                 1
#         190    80     480      320       300       150             150                 1
#                90     450      400       10        120             120                 1
#                                512       300       10              10                  1
#                       490      320       100       100             100                 1
#                       540      256       80        10              10                  1
#                100    450      320       150       10              10                  1
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
#                       512      512       240       100             100                 1
#                       520      400       100       10              10                  1
#
#                                                                                    dropout  \
#                                                                                       mean
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  0.3
#                       500      256       30        30              30                  0.3
#                                320       150       180             180                 0.3
#                90     450      512       180       100             100                 0.3
#                       500      320       150       50              50                  0.3
#                       512      320       30        180             180                 0.3
#                       530      320       30        100             100                 0.3
#                100    470      400       240       50              50                  0.3
#                110    530      256       120       150             150                 0.3
#                120    470      256       200       50              50                  0.3
#                       520      320       180       180             180                 0.3
#                130    520      512       10        180             180                 0.3
#                       530      400       100       100             100                 0.3
#         190    80     480      320       300       150             150                 0.3
#                90     450      400       10        120             120                 0.3
#                                512       300       10              10                  0.3
#                       490      320       100       100             100                 0.3
#                       540      256       80        10              10                  0.3
#                100    450      320       150       10              10                  0.3
#                       470      320       240       100             100                 0.3
#                       512      256       120       10              10                  0.3
#                                512       30        70              70                  0.3
#                       530      256       80        120             120                 0.3
#                       550      400       200       10              10                  0.3
#                110    480      400       100       120             120                 0.3
#                       540      400       10        100             100                 0.3
#                120    450      256       150       100             100                 0.3
#                       460      256       120       180             180                 0.3
#                       480      512       50        180             180                 0.3
#                       490      320       120       150             150                 0.3
# ...                                                                                    ...
# 50      230    100    490      320       200       50              50                  0.3
#                       550      256       120       120             120                 0.3
#                110    450      320       200       70              70                  0.3
#                       490      512       100       70              70                  0.3
#                       512      512       120       180             180                 0.3
#                       520      256       30        100             100                 0.3
#                                400       200       70              70                  0.3
#                       530      512       300       180             180                 0.3
#                130    460      256       180       120             120                 0.3
#                                400       50        120             120                 0.3
#                       480      400       150       50              50                  0.3
#                       550      400       100       70              70                  0.3
#         240    80     470      320       180       100             100                 0.3
#                       500      256       150       180             180                 0.3
#                       530      512       300       150             150                 0.3
#                       540      400       50        30              30                  0.3
#                100    460      320       120       150             150                 0.3
#                       490      512       150       30              30                  0.3
#                       500      512       80        180             180                 0.3
#                       530      400       300       10              10                  0.3
#                       550      256       30        100             100                 0.3
#                                          150       150             150                 0.3
#                                512       240       50              50                  0.3
#                120    470      256       200       100             100                 0.3
#                130    450      320       180       100             100                 0.3
#                       480      256       150       120             120                 0.3
#                       490      512       200       30              30                  0.3
#                       500      256       100       100             100                 0.3
#                       512      512       240       100             100                 0.3
#                       520      400       100       10              10                  0.3
#
#                                                                                           \
#                                                                                    count
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  1
#                       500      256       30        30              30                  1
#                                320       150       180             180                 1
#                90     450      512       180       100             100                 1
#                       500      320       150       50              50                  1
#                       512      320       30        180             180                 1
#                       530      320       30        100             100                 1
#                100    470      400       240       50              50                  1
#                110    530      256       120       150             150                 1
#                120    470      256       200       50              50                  1
#                       520      320       180       180             180                 1
#                130    520      512       10        180             180                 1
#                       530      400       100       100             100                 1
#         190    80     480      320       300       150             150                 1
#                90     450      400       10        120             120                 1
#                                512       300       10              10                  1
#                       490      320       100       100             100                 1
#                       540      256       80        10              10                  1
#                100    450      320       150       10              10                  1
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
# ...
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
#                       512      512       240       100             100                 1
#                       520      400       100       10              10                  1
#
#                                                                                    auc_freeze  \
#                                                                                          mean
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                 0.71197
#                       500      256       30        30              30                 0.71320
#                                320       150       180             180                0.71187
#                90     450      512       180       100             100                0.71244
#                       500      320       150       50              50                 0.71171
#                       512      320       30        180             180                0.71232
#                       530      320       30        100             100                0.71132
#                100    470      400       240       50              50                 0.71318
#                110    530      256       120       150             150                0.71058
#                120    470      256       200       50              50                 0.71238
#                       520      320       180       180             180                0.71304
#                130    520      512       10        180             180                0.71123
#                       530      400       100       100             100                0.71215
#         190    80     480      320       300       150             150                0.71218
#                90     450      400       10        120             120                0.71077
#                                512       300       10              10                 0.71337
#                       490      320       100       100             100                0.71152
#                       540      256       80        10              10                 0.71223
#                100    450      320       150       10              10                 0.71284
#                       470      320       240       100             100                0.71239
#                       512      256       120       10              10                 0.71197
#                                512       30        70              70                 0.71246
#                       530      256       80        120             120                0.71131
#                       550      400       200       10              10                 0.71194
#                110    480      400       100       120             120                0.71191
#                       540      400       10        100             100                0.71217
#                120    450      256       150       100             100                0.71111
#                       460      256       120       180             180                0.71215
#                       480      512       50        180             180                0.71207
#                       490      320       120       150             150                0.71237
# ...                                                                                       ...
# 50      230    100    490      320       200       50              50                 0.71265
#                       550      256       120       120             120                0.71215
#                110    450      320       200       70              70                 0.71173
#                       490      512       100       70              70                 0.71215
#                       512      512       120       180             180                0.71208
#                       520      256       30        100             100                0.71223
#                                400       200       70              70                 0.71137
#                       530      512       300       180             180                0.71267
#                130    460      256       180       120             120                0.71195
#                                400       50        120             120                0.71108
#                       480      400       150       50              50                 0.71134
#                       550      400       100       70              70                 0.71142
#         240    80     470      320       180       100             100                0.71069
#                       500      256       150       180             180                0.71143
#                       530      512       300       150             150                0.71229
#                       540      400       50        30              30                 0.71280
#                100    460      320       120       150             150                0.71173
#                       490      512       150       30              30                 0.71173
#                       500      512       80        180             180                0.71271
#                       530      400       300       10              10                 0.71266
#                       550      256       30        100             100                0.71146
#                                          150       150             150                0.71278
#                                512       240       50              50                 0.71273
#                120    470      256       200       100             100                0.71062
#                130    450      320       180       100             100                0.71191
#                       480      256       150       120             120                0.71118
#                       490      512       200       30              30                 0.71193
#                       500      256       100       100             100                0.71098
#                       512      512       240       100             100                0.71261
#                       520      400       100       10              10                 0.71224
#
#
#                                                                                    count
# DX1_dim DX_dim PR_dim fc_width batchsize count_cap DX_rarecutpoint PR_rarecutpoint
# 30      180    80     460      512       50        70              70                  1
#                       500      256       30        30              30                  1
#                                320       150       180             180                 1
#                90     450      512       180       100             100                 1
#                       500      320       150       50              50                  1
#                       512      320       30        180             180                 1
#                       530      320       30        100             100                 1
#                100    470      400       240       50              50                  1
#                110    530      256       120       150             150                 1
#                120    470      256       200       50              50                  1
#                       520      320       180       180             180                 1
#                130    520      512       10        180             180                 1
#                       530      400       100       100             100                 1
#         190    80     480      320       300       150             150                 1
#                90     450      400       10        120             120                 1
#                                512       300       10              10                  1
#                       490      320       100       100             100                 1
#                       540      256       80        10              10                  1
#                100    450      320       150       10              10                  1
#                       470      320       240       100             100                 1
#                       512      256       120       10              10                  1
#                                512       30        70              70                  1
#                       530      256       80        120             120                 1
#                       550      400       200       10              10                  1
#                110    480      400       100       120             120                 1
#                       540      400       10        100             100                 1
#                120    450      256       150       100             100                 1
#                       460      256       120       180             180                 1
#                       480      512       50        180             180                 1
#                       490      320       120       150             150                 1
# ...                                                                                  ...
# 50      230    100    490      320       200       50              50                  1
#                       550      256       120       120             120                 1
#                110    450      320       200       70              70                  1
#                       490      512       100       70              70                  1
#                       512      512       120       180             180                 1
#                       520      256       30        100             100                 1
#                                400       200       70              70                  1
#                       530      512       300       180             180                 1
#                130    460      256       180       120             120                 1
#                                400       50        120             120                 1
#                       480      400       150       50              50                  1
#                       550      400       100       70              70                  1
#         240    80     470      320       180       100             100                 1
#                       500      256       150       180             180                 1
#                       530      512       300       150             150                 1
#                       540      400       50        30              30                  1
#                100    460      320       120       150             150                 1
#                       490      512       150       30              30                  1
#                       500      512       80        180             180                 1
#                       530      400       300       10              10                  1
#                       550      256       30        100             100                 1
#                                          150       150             150                 1
#                                512       240       50              50                  1
#                120    470      256       200       100             100                 1
#                130    450      320       180       100             100                 1
#                       480      256       150       120             120                 1
#                       490      512       200       30              30                  1
#                       500      256       100       100             100                 1
#                       512      512       240       100             100                 1
#                       520      400       100       10              10                  1
#
# [600 rows x 22 columns]

# %%
res.columns
# Out:
# Index(['model_name', 'DX1_dim', 'DX_dim', 'PR_dim', 'hosp_embed_dim',
#        'fc_width', 'lr1', 'lr2', 'dropout', 'batchsize', 'embed_file',
#        'cohort', 'tst_seed', 'n_fold', 'count_cap', 'DX_rarecutpoint',
#        'PR_rarecutpoint', 'other_pred', 'ndxpr', 'auc_mean', 'auc_avg',
#        'auc_freeze', 'y_pred_file'],
#       dtype='object')

# %%
parallel_coord_df = res[['DX1_dim', 'DX_dim', 'PR_dim',
       'fc_width', 'batchsize',
        'count_cap', 'DX_rarecutpoint',
       'PR_rarecutpoint', 'auc_avg']]

# %%
parallel_coord_df.columns = ['DX1_dim', 'DX_dim', 'PR_dim',
       'fc_width', 'batchsize',
        'count_cap', 'DX_rarecutpoint',
       'PR_rarecutpoint', 'score']

# %%
dict_lst = []
for _, r in parallel_coord_df.iterrows():
    dict_lst.append(r.to_dict())

# %%
parallel_coordinates(dict_lst)

# %%
res.penalty.value_counts()
# Out:
# 0.5    30
# 0.0    30
# Name: penalty, dtype: int64

# %%
res_grouped = res.loc[(res.other_pred==1)&(res.auc_freeze>0.7175)].groupby(['model_name', 'DX1_dim', 'other_pred', 'count_cap', 
                          'penalty_metric','penalty'])

# %%
res_grouped = res.groupby(['model_name', 'code_embed_dim', 'count_cap', 'cohort', 
                          'metric','penalty'])

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#                                                           auc_freeze        \
#                                                                 mean count
# model_name code_embed_dim count_cap cohort metric penalty
# setsum     200            20.0      ami    cosine 0.0        0.71827    10
#                                                   0.5        0.71865    10
#                                     chf    cosine 0.0        0.62946    10
#                                                   0.5        0.62985    10
#                                     pna    cosine 0.0        0.67412    10
#                                                   0.5        0.67488    10
#
#                                                           auc_mean        \
#                                                               mean count
# model_name code_embed_dim count_cap cohort metric penalty
# setsum     200            20.0      ami    cosine 0.0      0.71907    10
#                                                   0.5      0.71936    10
#                                     chf    cosine 0.0      0.63058    10
#                                                   0.5      0.63099    10
#                                     pna    cosine 0.0      0.67541    10
#                                                   0.5      0.67588    10
#
#                                                            auc_avg
#                                                               mean count
# model_name code_embed_dim count_cap cohort metric penalty
# setsum     200            20.0      ami    cosine 0.0      0.72127    10
#                                                   0.5      0.72142    10
#                                     chf    cosine 0.0      0.63351    10
#                                                   0.5      0.63403    10
#                                     pna    cosine 0.0      0.67811    10
#                                                   0.5      0.67841    10

# %%
res = res.loc[(res.count_cap==5)&(res.penalty==0)]

# %%
res_grouped = res.groupby(['cohort', 'count_cap', 'penalty'])

# %%
res_grouped = res.groupby(['cohort'])

# %%
res_grouped[['auc_freeze', 'auc_mean', 'auc_avg']].agg(['mean', 'count'])
# Out:
#        auc_freeze        auc_mean         auc_avg
#              mean count      mean count      mean count
# cohort
# ami      0.675395    10  0.676062    10  0.679612    10
# chf      0.610980    10  0.612414    10  0.616564    10
# pna      0.648467    10  0.649521    10  0.653431    10

# %%
for n, g in res_grouped:
    print(n, 'freeze: {0:.3f} ({1:.3f})'.format(g.auc_freeze.mean(), g.auc_freeze.std()/np.sqrt(len(g))), 
         'mean: {0:.3f} ({1:.3f})'.format(g.auc_mean.mean(), g.auc_mean.std()/np.sqrt(len(g))), 
         'avg: {0:.3f} ({1:.3f})'.format(g.auc_avg.mean(), g.auc_avg.std()/np.sqrt(len(g))))
# Out:
# ami freeze: 0.715 (0.002) mean: 0.716 (0.002) avg: 0.718 (0.002)
# chf freeze: 0.625 (0.002) mean: 0.627 (0.002) avg: 0.630 (0.002)
# pna freeze: 0.671 (0.001) mean: 0.672 (0.001) avg: 0.675 (0.001)

# %%
for n, g in res_grouped:
    print(n, 'freeze: {0:.3f} ({1:.3f}, {2:.3f})'.format(g.auc_freeze.mean(), *sms.DescrStatsW(g.auc_freeze).zconfint_mean()), 
         'mean: {0:.3f} ({1:.3f}, {2:.3f})'.format(g.auc_mean.mean(), *sms.DescrStatsW(g.auc_mean).zconfint_mean()), 
         'avg: {0:.3f} ({1:.3f}, {2:.3f})'.format(g.auc_avg.mean(), *sms.DescrStatsW(g.auc_avg).zconfint_mean()))
# Out:
# ami freeze: 0.675 (0.672, 0.679) mean: 0.676 (0.673, 0.679) avg: 0.680 (0.676, 0.683)
# chf freeze: 0.611 (0.608, 0.614) mean: 0.612 (0.609, 0.616) avg: 0.617 (0.613, 0.620)
# pna freeze: 0.648 (0.646, 0.651) mean: 0.650 (0.646, 0.653) avg: 0.653 (0.650, 0.657)

# %%
res.to_csv('output/ht_result0215.csv', index=False)
