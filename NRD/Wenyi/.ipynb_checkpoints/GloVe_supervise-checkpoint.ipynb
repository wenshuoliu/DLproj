# %% [markdown]
# # Supervised GloVe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import statsmodels.api as sm
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import roc_curve, auc
import os, sys, time
from importlib import reload
# %matplotlib inline

# %%
path = '/nfs/turbo/umms-awaljee/wsliu/Data/MIMIC/'

# %%
model_path = path + 'models/'
if not os.path.exists(model_path): os.mkdir(model_path)

# %%
from keras.layers import Input, Embedding, Concatenate, Reshape, BatchNormalization, LSTM, CuDNNLSTM, CuDNNGRU, Lambda, Add
from keras.models import Model
from keras.layers.core import Dense, Activation, Dropout, RepeatVector
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.initializers import Constant
import keras.backend as K

module_path = '/home/wsliu/Codes/DLproj'
if module_path not in sys.path:
    sys.path.append(module_path)
if module_path+'/NRD' not in sys.path:
    sys.path.append(module_path+'/NRD')
from DL_utils import plot_roc
from keras_addon import AUCCheckPoint
from utils import get_frequency, preprocess

from ccs_tools import dx_multi, pr_multi, core_dtypes_pd, dx_label
# Out:
# Using TensorFlow backend.

# %%
from doublebatch import DoubleBatchGenerator

# %% [markdown]
# ## Data Preparation

# %%
all_df = pd.read_csv(path+'MIMIC3_Updated_include.csv')

# %%
all_df = all_df.drop(columns=['PR'+str(j) for j in range(15, 40)])

# %%
n_DX = 30
n_PR = 15
DXs = ['DX'+str(n) for n in range(1, n_DX+1)]
PRs = ['PR'+str(n) for n in range(1, n_PR+1)]

# %%
all_df.columns
# Out:
# Index(['Unnamed: 0', 'HADM_ID', 'MORTALITY_1year', 'AGE', 'GENDER', 'LOS',
#        'Eth', 'DX0', 'DX1', 'DX2', 'DX3', 'DX4', 'DX5', 'DX6', 'DX7', 'DX8',
#        'DX9', 'DX10', 'DX11', 'DX12', 'DX13', 'DX14', 'DX15', 'DX16', 'DX17',
#        'DX18', 'DX19', 'DX20', 'DX21', 'DX22', 'DX23', 'DX24', 'DX25', 'DX26',
#        'DX27', 'DX28', 'DX29', 'PR0', 'PR1', 'PR2', 'PR3', 'PR4', 'PR5', 'PR6',
#        'PR7', 'PR8', 'PR9', 'PR10', 'PR11', 'PR12', 'PR13', 'PR14'],
#       dtype='object')

# %%
all_df.columns = ['Unnamed: 0', 'HADM_ID', 'MORTALITY_1year', 'AGE', 'GENDER', 'LOS', 'Eth'] + DXs + PRs

# %%
all_df.shape
# Out:
# (45348, 52)

# %%
DX_series = pd.Series()
for dx in DXs:
    DX_series = pd.concat([DX_series, all_df[dx]])

PR_series = pd.Series()
for pr in PRs:
    PR_series = pd.concat([PR_series, all_df[pr]])

# %%
DX_freq = DX_series.value_counts()
PR_freq = PR_series.value_counts()

# %%
DX_rarecutpoint = 21
PR_rarecutpoint = 21

# %%
DX_cat = sorted(DX_freq.loc[DX_freq>=DX_rarecutpoint].index)
PR_cat = sorted(PR_freq.loc[PR_freq>=PR_rarecutpoint].index)
DX_in = set(DX_cat)
PR_in = set(PR_cat)

code_cat = ['missing'] + DX_cat + PR_cat

# %%
len(DX_in), len(PR_in)
# Out:
# (1731, 558)

# %%
clean_df = all_df.copy()
for dx in DXs:
    clean_df.loc[~clean_df[dx].isin(DX_in), dx] = 'missing'
for pr in PRs:
    clean_df.loc[~clean_df[pr].isin(PR_in), pr] = 'missing'

# %%
clean_df = clean_df.loc[(clean_df[DXs] != 'missing').sum(axis=1)>0]
clean_df = clean_df.loc[(clean_df[PRs] != 'missing').sum(axis=1)>0]

# %%
len(all_df), len(clean_df)
# Out:
# (45348, 44997)

# %%
all_df = clean_df.reset_index(drop=True)

# %%
DX_dict = dict(zip(DX_cat, range(1, len(DX_cat)+1)))
PR_dict = dict(zip(PR_cat, range(len(DX_cat)+1, len(DX_cat)+len(PR_cat)+1)))

DX_dict['missing'] = 0
PR_dict['missing'] = 0

# %%
int_df = all_df.copy()
for dx in DXs:
    int_df[dx] = int_df[dx].map(DX_dict)
    
for pr in PRs:
    int_df[pr] = int_df[pr].map(PR_dict)

# %%
int_df.PR1.max(), len(code_cat)
# Out:
# (2289, 2290)

# %%
all_df = int_df.reset_index(drop=True)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=24)

train_idx, tst_idx = next(kf.split(all_df))

train_df0 = all_df.loc[train_idx].reset_index(drop=True)
tst_df = all_df.loc[tst_idx].reset_index(drop=True)

# %%
set(train_df0.HADM_ID).intersection(set(tst_df.HADM_ID)), len(train_df0), len(tst_df)
# Out:
# (set(), 35997, 9000)

# %% [markdown]
# ### Collect Co-occurence Counts by Glove class

# %%
from glove import Glove

# %%
code_embed_dim=30
count_cap=20

# %%
g = Glove(input_dim=len(code_cat), embedding_dim=code_embed_dim, count_cap=count_cap)

# %%
g.update_cooccur(train_df0[DXs+PRs])
# Out:
# Updating co-occurrence matrix from a Dataframe with 35997 rows...
# Finished. It takes 5.2 seconds to update the cooccurrences.

# %%
cooccur_df = g.get_cooccur_df()

# %%
g.train_glove(cooccur_df=cooccur_df, cache_path=model_path+'temp/', batch_size=1024, epochs=80, reducelr_patience=3)
# Out:
# Preparing data...
# Defining the GloVe model...
# Training the GloVe model...
# Epoch 1/80
# 601355/601355 [==============================] - 4s 6us/step - loss: 0.7326
# Epoch 2/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.1546
# Epoch 3/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.1424
# Epoch 4/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.1340
# Epoch 5/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.1210
# Epoch 6/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.1055
# Epoch 7/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0935
# Epoch 8/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0842
# Epoch 9/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0764
# Epoch 10/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0700
# Epoch 11/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0648
# Epoch 12/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0606
# Epoch 13/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0571
# Epoch 14/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0543
# Epoch 15/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0521
# Epoch 16/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0502
# Epoch 17/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0487
# Epoch 18/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0473
# Epoch 19/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0463
# Epoch 20/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0453
# Epoch 21/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0445
# Epoch 22/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0439
# Epoch 23/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0433
# Epoch 24/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0428
# Epoch 25/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0424
# Epoch 26/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0420
# Epoch 27/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0417
# Epoch 28/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0415
# Epoch 29/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0412
# Epoch 30/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0410
# Epoch 31/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0409
# Epoch 32/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0407
# Epoch 33/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0406
# Epoch 34/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0404
# Epoch 35/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0403
# Epoch 36/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0402
# Epoch 37/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0401
# Epoch 38/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0400
# Epoch 39/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0400
# Epoch 40/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0399
# Epoch 41/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0398
# Epoch 42/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0398
# Epoch 43/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0397
# Epoch 44/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0397
# Epoch 45/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0396
# Epoch 46/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0396
# Epoch 47/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0395
# Epoch 48/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0395
# Epoch 49/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0395
# Epoch 50/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0394
# Epoch 51/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0394
# Epoch 52/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0394
# Epoch 53/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0393
# Epoch 54/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0393
# Epoch 55/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0380
# Epoch 56/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0379
# Epoch 57/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0379
# Epoch 58/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0379
# Epoch 59/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0378
# Epoch 60/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0375
# Epoch 61/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0375
# Epoch 62/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0375
# Epoch 63/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0375
# Epoch 64/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 65/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 66/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 67/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 68/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0374
# Epoch 69/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0374
# Epoch 70/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 71/80
# 601355/601355 [==============================] - 2s 4us/step - loss: 0.0374
# Epoch 72/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 73/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 74/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 75/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 76/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 77/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 78/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 79/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Epoch 80/80
# 601355/601355 [==============================] - 2s 3us/step - loss: 0.0374
# Finished. The pretrained embedding matrix can be retrieved by .get_embed_mat().

# %%
embed_mat = g.get_embed_mat()

# %%
cooccur_df.shape, train_df0.shape, len(cooccur_df)/len(train_df0)
# Out:
# ((461914, 3), (35770, 52), 12.913447022644675)

# %% [markdown]
# ### Data formating

# %%
train_df = train_df0.copy()

# %%
n_fold = 5

# %%
kf2 = KFold(n_splits=n_fold, random_state=23, shuffle=True)

# %%
trn_idx, val_idx = next(kf2.split(train_df))

# %%
trn_df = train_df.loc[trn_idx].reset_index(drop=True)
val_df = train_df.loc[val_idx].reset_index(drop=True)

# %% [markdown]
# ### Data Generator

# %%
from keras.utils import Sequence

# %%
readm_batchsize = 256
batchsize_ratio = 12

# %%
class DoubleBatchGenerator(Sequence):
    'Generates data from two datasets'
    def __init__(self, cooccur_df, readm_df, readm_batchsize=512, batchsize_ratio=16, shuffle=True, scaling_factor=0.75, 
                count_cap=20):
        '''Initialization
        Here coocur_df and readm_df need to have integer index from 0, i.e. they need to reset_index()'''
        self.readm_batchsize = readm_batchsize
        self.cooccur_batchsize = readm_batchsize*batchsize_ratio
        self.batchsize_ratio = batchsize_ratio
        self.cooccur_df = cooccur_df
        self.readm_df = readm_df
        self.shuffle = shuffle
        self.__scaling_factor = scaling_factor
        self.__count_cap = count_cap
        self.batch_size = self.readm_batchsize
        self.n = self.__len__()*self.batch_size
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        readm_steps = np.floor(len(self.readm_df) / self.readm_batchsize)
        cooccur_steps = np.floor(len(self.cooccur_df)/self.cooccur_batchsize)
        return int(np.min((readm_steps, cooccur_steps)))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        readm_indexes = self.readm_indexes[index*self.readm_batchsize:(index+1)*self.readm_batchsize]
        cooccur_indexes = self.cooccur_indexes[index*self.cooccur_batchsize:(index+1)*self.cooccur_batchsize]

        DX_mat = self.readm_df.loc[readm_indexes, DXs].values
        PR_mat = self.readm_df.loc[readm_indexes, PRs].values
        continue_mat = self.readm_df.loc[readm_indexes, ['AGE', 'GENDER', 'LOS']].values
        eth_array = self.readm_df.loc[readm_indexes, 'Eth'].values
        eth_mat = to_categorical(eth_array, num_classes=5)
        other_mat = np.concatenate((continue_mat, eth_mat), axis=1)
        y_readm = self.readm_df.loc[readm_indexes, 'MORTALITY_1year'].astype(int).values
        Y_readm = to_categorical(y_readm, num_classes=2)

        focal_id = self.cooccur_df.loc[cooccur_indexes, 'focal_index'].values
        context_id = self.cooccur_df.loc[cooccur_indexes, 'context_index'].values
        y_cooccur = np.log(self.cooccur_df.loc[cooccur_indexes, 'cooccur_counts'].values)
        
        focal_id = np.reshape(focal_id, (self.readm_batchsize, self.batchsize_ratio))
        context_id = np.reshape(context_id, (self.readm_batchsize, self.batchsize_ratio))
        y_cooccur = np.reshape(y_cooccur, (self.readm_batchsize, self.batchsize_ratio))

        return [DX_mat, PR_mat, other_mat, focal_id, context_id], [Y_readm, y_cooccur]

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.readm_indexes = np.arange(len(self.readm_df))
        self.cooccur_indexes = np.arange(len(self.cooccur_df))
        if self.shuffle == True:
            np.random.shuffle(self.readm_indexes)
            np.random.shuffle(self.cooccur_indexes)

# %%
trn_gen = DoubleBatchGenerator(cooccur_df=cooccur_df, readm_df=trn_df, readm_batchsize=readm_batchsize, 
                               batchsize_ratio=batchsize_ratio, shuffle=True)

# %%
val_gen = DoubleBatchGenerator(cooccur_df=cooccur_df, readm_df=val_df, readm_batchsize=len(val_df), 
                               batchsize_ratio=batchsize_ratio, shuffle=False)

tst_gen = DoubleBatchGenerator(cooccur_df=cooccur_df, readm_df=tst_df, readm_batchsize=len(tst_df), 
                               batchsize_ratio=batchsize_ratio, shuffle=False)

# %%
val_x, val_y = next(iter(val_gen))

# %%
len(trn_df)/readm_batchsize, len(val_df)/readm_batchsize, len(cooccur_df)/readm_batchsize/batchsize_ratio
# Out:
# (112.48828125, 28.125, 195.75358072916666)

# %% [markdown]
# ### Model Building

# %%
from setsum_layer import SetSum, MaskedSum, MaskedDense, MaskedPooling
from keras.layers import Multiply

# %%
from keras_multi_head import MultiHeadAttention

# %%
code_embed_dim = 30
md_width = 8
fc_width = 512
dropout = 0.3
job_index = 0
parent_pairs = None

# %%
embed_initializer = Constant(embed_mat)

# %%
embed_initializer = 'uniform'

# %%
input_w = Input(shape=(batchsize_ratio,), name='focal_index')
input_v = Input(shape=(batchsize_ratio,), name='context_index')
if parent_pairs is None:
    embed_layer = Embedding(input_dim=len(code_cat), output_dim=code_embed_dim, name='embed', 
                            embeddings_initializer=embed_initializer)
else:
    embed_layer = Embedding(input_dim=len(code_cat), output_dim=code_embed_dim, name='embed',
                            embeddings_regularizer=Parent_reg(parent_pairs, lamb, metric))
w_embed = embed_layer(input_w)
v_embed = embed_layer(input_v)
bias_layer = Embedding(input_dim=len(code_cat), output_dim=1, name='bias')
w_bias = bias_layer(input_w)
v_bias = bias_layer(input_v)

inner = Multiply()([w_embed, v_embed])
inner = Lambda(lambda x: K.sum(x, axis=-1, keepdims=True))(inner)

merged = Concatenate(axis=-1)([inner, w_bias, v_bias])

output_cooccur = Lambda(lambda x: K.sum(x, axis=-1, keepdims=False), name='cooccur')(merged)

input_DX = Input(shape = (len(DXs),))
DX_embed = embed_layer(input_DX)
DX_embed = MaskedDense(md_width, activation='relu')(DX_embed)
DX_embed = MaskedSum()(DX_embed)
input_PR = Input(shape = (len(PRs),))
PR_embed = embed_layer(input_PR)
PR_embed = MaskedDense(md_width, activation='relu')(PR_embed)
PR_embed = MaskedSum()(PR_embed)
input_other = Input(shape=(8, ))
merged = Concatenate(axis=1)([DX_embed, PR_embed, input_other])
merged = Dense(fc_width, activation='relu')(merged)
merged = Dropout(dropout)(merged)
output_readm = Dense(2, activation='softmax', name='readm')(merged)

model = Model(inputs=[input_DX, input_PR, input_other, input_w, input_v], 
              outputs=[output_readm, output_cooccur])

# %%
count_cap = 20
scaling_factor = 0.75
def weighting_factor(count):
    ge_mask = K.cast(K.greater_equal(count, count_cap), K.floatx())
    l_mask = K.cast(K.less(count, count_cap), K.floatx())
    return 1.*ge_mask + np.power(count/count_cap, scaling_factor)*l_mask

def loss_cooccur(y_true, y_pred):
    weight_cooccur = weighting_factor(K.exp(y_true))
    return K.mean(K.square(y_pred - y_true)*weight_cooccur)

# %%
adam = Adam(lr=5e-4)
model.compile(loss={'readm':'categorical_crossentropy', 'cooccur':loss_cooccur}, 
             optimizer=adam, 
             loss_weights={'readm':1., 'cooccur':10.})

# %%
auccheckpoint = AUCCheckPoint(filepath=model_path+'embeding_nn_temp'+str(job_index)+'.h5', validation_x=val_x, validation_y=val_y,
                              auc_output_idx=[0])
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=K.epsilon())
#earlystop = EarlyStopping(monitor='val_loss', patience=20)

# %%
class_weight = {'readm':{0:1., 1:5.}}

# %%
hist = model.fit_generator(generator=trn_gen, validation_data=val_gen, epochs=50, verbose=1, 
                           callbacks=[auccheckpoint, reduce_lr], class_weight=class_weight)
# Out:
# Epoch 1/50
# 112/112 [==============================] - 3s 27ms/step - loss: 3.5448 - readm_loss: 2.0399 - cooccur_loss: 0.1505 - val_loss: 1.8079 - val_readm_loss: 0.5699 - val_cooccur_loss: 0.1238
# AUC_readm: 0.7946
# Mean AUC: 0.7946
#
# Epoch 2/50
# 112/112 [==============================] - 2s 14ms/step - loss: 2.4054 - readm_loss: 1.3405 - cooccur_loss: 0.1065 - val_loss: 1.6089 - val_readm_loss: 0.6760 - val_cooccur_loss: 0.0933
# AUC_readm: 0.8209
# Mean AUC: 0.8209
#
# Epoch 3/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.8602 - readm_loss: 1.0197 - cooccur_loss: 0.0840 - val_loss: 1.2076 - val_readm_loss: 0.4404 - val_cooccur_loss: 0.0767
# AUC_readm: 0.8329
# Mean AUC: 0.8329
#
# Epoch 4/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.5958 - readm_loss: 0.8867 - cooccur_loss: 0.0709 - val_loss: 1.1901 - val_readm_loss: 0.5200 - val_cooccur_loss: 0.0670
# AUC_readm: 0.8441
# Mean AUC: 0.8441
#
# Epoch 5/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.4590 - readm_loss: 0.8211 - cooccur_loss: 0.0638 - val_loss: 1.0100 - val_readm_loss: 0.4000 - val_cooccur_loss: 0.0610
# AUC_readm: 0.8500
# Mean AUC: 0.8500
#
# Epoch 6/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.3715 - readm_loss: 0.7821 - cooccur_loss: 0.0589 - val_loss: 0.9858 - val_readm_loss: 0.4129 - val_cooccur_loss: 0.0573
# AUC_readm: 0.8559
# Mean AUC: 0.8559
#
# Epoch 7/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.3194 - readm_loss: 0.7600 - cooccur_loss: 0.0559 - val_loss: 0.9955 - val_readm_loss: 0.4479 - val_cooccur_loss: 0.0548
# AUC_readm: 0.8599
# Mean AUC: 0.8599
#
# Epoch 8/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2826 - readm_loss: 0.7420 - cooccur_loss: 0.0541 - val_loss: 0.9534 - val_readm_loss: 0.4240 - val_cooccur_loss: 0.0529
# AUC_readm: 0.8614
# Mean AUC: 0.8614
#
# Epoch 9/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2510 - readm_loss: 0.7277 - cooccur_loss: 0.0523 - val_loss: 0.9062 - val_readm_loss: 0.3904 - val_cooccur_loss: 0.0516
# AUC_readm: 0.8620
# Mean AUC: 0.8620
#
# Epoch 10/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2361 - readm_loss: 0.7261 - cooccur_loss: 0.0510 - val_loss: 0.9128 - val_readm_loss: 0.4082 - val_cooccur_loss: 0.0505
# AUC_readm: 0.8643
# Mean AUC: 0.8643
#
# Epoch 11/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2233 - readm_loss: 0.7235 - cooccur_loss: 0.0500 - val_loss: 0.9025 - val_readm_loss: 0.4072 - val_cooccur_loss: 0.0495
# AUC_readm: 0.8668
# Mean AUC: 0.8668
#
# Epoch 12/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1953 - readm_loss: 0.7057 - cooccur_loss: 0.0490 - val_loss: 0.8861 - val_readm_loss: 0.3988 - val_cooccur_loss: 0.0487
# AUC_readm: 0.8661
# Mean AUC: 0.8661
#
# Epoch 13/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1905 - readm_loss: 0.7054 - cooccur_loss: 0.0485 - val_loss: 0.8726 - val_readm_loss: 0.3923 - val_cooccur_loss: 0.0480
# AUC_readm: 0.8670
# Mean AUC: 0.8670
#
# Epoch 14/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1733 - readm_loss: 0.6998 - cooccur_loss: 0.0473 - val_loss: 0.8837 - val_readm_loss: 0.4099 - val_cooccur_loss: 0.0474
# AUC_readm: 0.8684
# Mean AUC: 0.8684
#
# Epoch 15/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1592 - readm_loss: 0.6883 - cooccur_loss: 0.0471 - val_loss: 0.9746 - val_readm_loss: 0.5064 - val_cooccur_loss: 0.0468
# AUC_readm: 0.8681
# Mean AUC: 0.8681
#
# Epoch 16/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1470 - readm_loss: 0.6860 - cooccur_loss: 0.0461 - val_loss: 0.8335 - val_readm_loss: 0.3710 - val_cooccur_loss: 0.0463
# AUC_readm: 0.8707
# Mean AUC: 0.8707
#
# Epoch 17/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1423 - readm_loss: 0.6806 - cooccur_loss: 0.0462 - val_loss: 0.8412 - val_readm_loss: 0.3834 - val_cooccur_loss: 0.0458
# AUC_readm: 0.8687
# Mean AUC: 0.8687
#
# Epoch 18/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1342 - readm_loss: 0.6799 - cooccur_loss: 0.0454 - val_loss: 0.8463 - val_readm_loss: 0.3928 - val_cooccur_loss: 0.0453
# AUC_readm: 0.8705
# Mean AUC: 0.8705
#
# Epoch 19/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1307 - readm_loss: 0.6782 - cooccur_loss: 0.0453 - val_loss: 0.8472 - val_readm_loss: 0.3978 - val_cooccur_loss: 0.0449
# AUC_readm: 0.8697
# Mean AUC: 0.8697
#
# Epoch 20/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1174 - readm_loss: 0.6724 - cooccur_loss: 0.0445 - val_loss: 0.8598 - val_readm_loss: 0.4142 - val_cooccur_loss: 0.0446
# AUC_readm: 0.8724
# Mean AUC: 0.8724
#
# Epoch 21/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1111 - readm_loss: 0.6663 - cooccur_loss: 0.0445 - val_loss: 0.8364 - val_readm_loss: 0.3941 - val_cooccur_loss: 0.0442
# AUC_readm: 0.8692
# Mean AUC: 0.8692
#
# Epoch 22/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0993 - readm_loss: 0.6588 - cooccur_loss: 0.0441 - val_loss: 0.8225 - val_readm_loss: 0.3835 - val_cooccur_loss: 0.0439
# AUC_readm: 0.8723
# Mean AUC: 0.8723
#
# Epoch 23/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0962 - readm_loss: 0.6585 - cooccur_loss: 0.0438 - val_loss: 0.8270 - val_readm_loss: 0.3911 - val_cooccur_loss: 0.0436
# AUC_readm: 0.8720
# Mean AUC: 0.8720
#
# Epoch 24/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0903 - readm_loss: 0.6558 - cooccur_loss: 0.0434 - val_loss: 0.8625 - val_readm_loss: 0.4294 - val_cooccur_loss: 0.0433
# AUC_readm: 0.8716
# Mean AUC: 0.8716
#
# Epoch 25/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0779 - readm_loss: 0.6489 - cooccur_loss: 0.0429 - val_loss: 0.8051 - val_readm_loss: 0.3744 - val_cooccur_loss: 0.0431
# AUC_readm: 0.8720
# Mean AUC: 0.8720
#
# Epoch 26/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0743 - readm_loss: 0.6452 - cooccur_loss: 0.0429 - val_loss: 0.9371 - val_readm_loss: 0.5088 - val_cooccur_loss: 0.0428
# AUC_readm: 0.8699
# Mean AUC: 0.8699
#
# Epoch 27/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0728 - readm_loss: 0.6458 - cooccur_loss: 0.0427 - val_loss: 0.8363 - val_readm_loss: 0.4098 - val_cooccur_loss: 0.0426
# AUC_readm: 0.8711
# Mean AUC: 0.8711
#
# Epoch 28/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0677 - readm_loss: 0.6433 - cooccur_loss: 0.0424 - val_loss: 0.8712 - val_readm_loss: 0.4472 - val_cooccur_loss: 0.0424
# AUC_readm: 0.8719
# Mean AUC: 0.8719
#
# Epoch 29/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0588 - readm_loss: 0.6358 - cooccur_loss: 0.0423 - val_loss: 0.8353 - val_readm_loss: 0.4132 - val_cooccur_loss: 0.0422
# AUC_readm: 0.8697
# Mean AUC: 0.8697
#
# Epoch 30/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0542 - readm_loss: 0.6326 - cooccur_loss: 0.0422 - val_loss: 0.8428 - val_readm_loss: 0.4223 - val_cooccur_loss: 0.0421
# AUC_readm: 0.8699
# Mean AUC: 0.8699
#
# Epoch 31/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0517 - readm_loss: 0.6325 - cooccur_loss: 0.0419 - val_loss: 0.8760 - val_readm_loss: 0.4566 - val_cooccur_loss: 0.0419
# AUC_readm: 0.8722
# Mean AUC: 0.8722
#
# Epoch 32/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0437 - readm_loss: 0.6259 - cooccur_loss: 0.0418 - val_loss: 0.8403 - val_readm_loss: 0.4218 - val_cooccur_loss: 0.0418
# AUC_readm: 0.8705
# Mean AUC: 0.8705
#
# Epoch 33/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0412 - readm_loss: 0.6247 - cooccur_loss: 0.0417 - val_loss: 0.8732 - val_readm_loss: 0.4563 - val_cooccur_loss: 0.0417
# AUC_readm: 0.8705
# Mean AUC: 0.8705
#
# Epoch 34/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0258 - readm_loss: 0.6124 - cooccur_loss: 0.0413 - val_loss: 0.7970 - val_readm_loss: 0.3806 - val_cooccur_loss: 0.0416
# AUC_readm: 0.8704
# Mean AUC: 0.8704
#
# Epoch 35/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0207 - readm_loss: 0.6085 - cooccur_loss: 0.0412 - val_loss: 0.8403 - val_readm_loss: 0.4244 - val_cooccur_loss: 0.0416
# AUC_readm: 0.8700
# Mean AUC: 0.8700
#
# Epoch 36/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0180 - readm_loss: 0.6065 - cooccur_loss: 0.0412 - val_loss: 0.8122 - val_readm_loss: 0.3967 - val_cooccur_loss: 0.0416
# AUC_readm: 0.8702
# Mean AUC: 0.8702
#
# Epoch 37/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0182 - readm_loss: 0.6039 - cooccur_loss: 0.0414 - val_loss: 0.7906 - val_readm_loss: 0.3754 - val_cooccur_loss: 0.0415
# AUC_readm: 0.8703
# Mean AUC: 0.8703
#
# Epoch 38/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0204 - readm_loss: 0.6072 - cooccur_loss: 0.0413 - val_loss: 0.8233 - val_readm_loss: 0.4084 - val_cooccur_loss: 0.0415
# AUC_readm: 0.8692
# Mean AUC: 0.8692
#
# Epoch 39/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0151 - readm_loss: 0.6053 - cooccur_loss: 0.0410 - val_loss: 0.8093 - val_readm_loss: 0.3947 - val_cooccur_loss: 0.0415
# AUC_readm: 0.8696
# Mean AUC: 0.8696
#
# Epoch 40/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0140 - readm_loss: 0.6043 - cooccur_loss: 0.0410 - val_loss: 0.8319 - val_readm_loss: 0.4176 - val_cooccur_loss: 0.0414
# AUC_readm: 0.8688
# Mean AUC: 0.8688
#
# Epoch 41/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0171 - readm_loss: 0.6050 - cooccur_loss: 0.0412 - val_loss: 0.7973 - val_readm_loss: 0.3833 - val_cooccur_loss: 0.0414
# AUC_readm: 0.8695
# Mean AUC: 0.8695
#
# Epoch 42/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0121 - readm_loss: 0.6009 - cooccur_loss: 0.0411 - val_loss: 0.8315 - val_readm_loss: 0.4177 - val_cooccur_loss: 0.0414
# AUC_readm: 0.8685
# Mean AUC: 0.8685
#
# Epoch 43/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0140 - readm_loss: 0.6012 - cooccur_loss: 0.0413 - val_loss: 0.8175 - val_readm_loss: 0.4040 - val_cooccur_loss: 0.0414
# AUC_readm: 0.8690
# Mean AUC: 0.8690
#
# Epoch 44/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0097 - readm_loss: 0.5998 - cooccur_loss: 0.0410 - val_loss: 0.8375 - val_readm_loss: 0.4241 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8681
# Mean AUC: 0.8681
#
# Epoch 45/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0094 - readm_loss: 0.5998 - cooccur_loss: 0.0410 - val_loss: 0.8172 - val_readm_loss: 0.4041 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8690
# Mean AUC: 0.8690
#
# Epoch 46/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0066 - readm_loss: 0.5959 - cooccur_loss: 0.0411 - val_loss: 0.8135 - val_readm_loss: 0.4005 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8688
# Mean AUC: 0.8688
#
# Epoch 47/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0051 - readm_loss: 0.5960 - cooccur_loss: 0.0409 - val_loss: 0.8175 - val_readm_loss: 0.4046 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8686
# Mean AUC: 0.8686
#
# Epoch 48/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0061 - readm_loss: 0.5972 - cooccur_loss: 0.0409 - val_loss: 0.8246 - val_readm_loss: 0.4117 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8684
# Mean AUC: 0.8684
#
# Epoch 49/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0052 - readm_loss: 0.5955 - cooccur_loss: 0.0410 - val_loss: 0.8225 - val_readm_loss: 0.4097 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8684
# Mean AUC: 0.8684
#
# Epoch 50/50
# 112/112 [==============================] - 2s 14ms/step - loss: 1.0051 - readm_loss: 0.5951 - cooccur_loss: 0.0410 - val_loss: 0.8250 - val_readm_loss: 0.4123 - val_cooccur_loss: 0.0413
# AUC_readm: 0.8684
# Mean AUC: 0.8684

# %%
plt.plot(hist.history['val_loss'])

# %%
plt.plot(hist.history['lr'])

# %%
plt.plot(auccheckpoint.auc_history['readm'])

# %%
model.load_weights(model_path+'embeding_nn_temp'+str(job_index)+'.h5')

# %%
y = model.predict_generator(tst_gen, verbose=1)

y_pred = y[0][:, 1]
y_true = tst_df.MORTALITY_1year.astype(int).values
# Out:
# 1/1 [==============================] - 0s 89ms/step

# %%
plot_roc(y_pred, y_true)
# Out:
# {0: 0.8751385225171326}
