# %%
import tensorflow as tf

# %%
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
a = tf.constant(5)
b = tf.constant(6)
sess = tf.Session()
sess.run(a+b)
sess.close()

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1876273982070420021
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11277818266
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 12480189600601508614
# physical_device_desc: "device: 0, name: Tesla K40m, pci bus id: 0000:82:00.0, compute capability: 3.5"
# ]

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            0.2.0
# accelerate                         2.3.1
# aioeasywebdav                      2.2.0
# aiohttp                            3.3.2
# alabaster                          0.7.11
# anaconda-clean                     1.0
# anaconda-client                    1.7.1
# anaconda-navigator                 1.8.7
# anaconda-project                   0.8.2
# appdirs                            1.4.3
# argcomplete                        1.9.4
# asn1crypto                         0.24.0
# aspy.yaml                          0.3.0
# astor                              0.6.2
# astroid                            2.0.4
# astropy                            3.0.4
# async-timeout                      3.0.0
# atomicwrites                       1.1.5
# attrs                              18.1.0
# Automat                            0.7.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.csv                      1.0.1
# backports.shutil-get-terminal-size 1.0.0
# backports.weakref                  1.0rc1
# bcbio-gff                          0.6.4
# bcrypt                             3.1.4
# beautifulsoup4                     4.6.3
# biopython                          1.68
# bitarray                           0.8.3
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             1.5.0
# bokeh                              0.13.0
# boto                               2.49.0
# boto3                              1.7.62
# botocore                           1.10.62
# Bottleneck                         1.2.1
# brewer2mpl                         1.4.1
# bz2file                            0.98
# cached-property                    1.3.0
# certifi                            2018.8.13
# cffi                               1.11.5
# chardet                            3.0.4
# chest                              0.2.3
# click                              6.7
# cloudpickle                        0.5.3
# clyent                             1.2.2
# colorama                           0.3.9
# colormath                          3.0.0
# conda                              4.5.10
# conda-build                        3.10.9
# conda-verify                       3.0.2
# configobj                          5.0.6
# constantly                         15.1.0
# contextlib2                        0.5.5
# coverage                           4.5.1
# cryptography                       2.3
# cryptography-vectors               2.3
# cutadapt                           1.16
# cvxopt                             1.1.8
# cycler                             0.10.0
# Cython                             0.28.5
# cytoolz                            0.9.0.1
# dask                               0.18.2
# datashape                          0.5.4
# decorator                          4.3.0
# deepTools                          3.1.1
# dicom                              0.9.9.post1
# dill                               0.2.8.2
# distributed                        1.22.1
# docutils                           0.14
# dropbox                            5.2.1
# dynd                               0.7.3.dev1
# ecdsa                              0.13
# emcee                              2.2.1
# entrypoints                        0.2.3
# enum34                             1.1.6
# et-xmlfile                         1.0.1
# fastcache                          1.0.2
# filechunkio                        1.6
# filelock                           3.0.4
# Flask                              1.0.2
# Flask-Cors                         3.0.6
# ftputil                            3.2
# future                             0.16.0
# gast                               0.2.0
# gensim                             1.0.1
# gevent                             1.1rc4
# ggplot                             0.11.5
# glob2                              0.4.1
# gmpy2                              2.0.8
# greenlet                           0.4.14
# grpcio                             1.11.0
# h5py                               2.8.0
# heapdict                           1.0.0
# html5lib                           0.9999999
# hyperlink                          18.0.0
# hypothesis                         3.57.0
# idna                               2.7
# idna-ssl                           1.0.1
# imageai                            2.0.1
# imageio                            2.3.0
# imagesize                          1.0.0
# incremental                        17.5.0
# iopro                              1.7.2
# ipykernel                          4.8.2
# ipyparallel                        6.2.2
# ipython                            6.5.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.4.0
# isort                              4.3.4
# itsdangerous                       0.24
# jdcal                              1.4
# jedi                               0.12.1
# Jinja2                             2.10
# jmespath                           0.9.3
# joblib                             0.12.2
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     5.2.3
# jupyter-console                    5.2.0
# jupyter-core                       4.4.0
# Keras                              2.2.2
# Keras-Applications                 1.0.2
# Keras-Preprocessing                1.0.1
# kiwisolver                         1.0.1
# lazy-object-proxy                  1.3.1
# llvmlite                           0.15.0
# locket                             0.2.0
# lxml                               4.2.4
# lzstring                           1.0.3
# Mako                               1.0.7
# Markdown                           2.6.11
# MarkupSafe                         1.0
# matplotlib                         2.2.2
# matplotlib-venn                    0.11.5
# mccabe                             0.6.1
# metakernel                         0.20.1
# mistune                            0.8.3
# mmtf-python                        1.0.2
# mock                               2.0.0
# more-itertools                     4.3.0
# mpi4py                             2.0.0
# mpmath                             1.0.0
# msgpack                            0.5.6
# MulticoreTSNE                      0.1
# multidict                          4.3.1
# multipledispatch                   0.5.0
# multiqc                            1.6
# nb-anacondacloud                   1.4.0
# nb-conda                           2.2.1
# nb-conda-kernels                   2.1.0
# nbconvert                          5.3.1
# nbformat                           4.4.0
# nbpresent                          3.0.2
# networkx                           2.0
# nltk                               3.3
# nodeenv                            1.1.2
# nose                               1.3.7
# notebook                           5.6.0
# numba                              0.30.1
# numexpr                            2.6.5
# numpy                              1.14.2
# numpydoc                           0.8.0
# odo                                0.5.1
# olefile                            0.45.1
# opencv-python                      3.4.1.15
# openpyxl                           2.4.0b1
# packaging                          17.1
# pandas                             0.23.4
# pandocfilters                      1.4.2
# paramiko                           1.18.4
# parso                              0.3.1
# partd                              0.3.8
# path.py                            11.0.1
# pathlib2                           2.3.2
# patsy                              0.5.0
# pbr                                4.2.0
# pep8                               1.7.1
# pexpect                            4.6.0
# pickleshare                        0.7.4
# Pillow                             5.1.0
# pip                                18.1
# pkginfo                            1.4.2
# plotly                             3.1.0
# pluggy                             0.7.1
# ply                                3.11
# pre-commit                         0.13.6
# prometheus-client                  0.3.1
# prompt-toolkit                     1.0.15
# protobuf                           3.5.2
# psutil                             5.4.6
# psycopg2                           2.7.5
# ptyprocess                         0.6.0
# py                                 1.5.4
# py2bit                             0.3.0
# pyasn1                             0.4.4
# pyasn1-modules                     0.0.5
# pyBigWig                           0.3.11
# pycodestyle                        2.4.0
# pycosat                            0.6.3
# pycparser                          2.18
# pycrypto                           2.6.1
# pycuda                             2016.1.2
# pycurl                             7.43.0.2
# pydicom                            1.0.2
# pydot                              1.2.4
# PyDSTool                           0.90.2
# pyfasta                            0.5.2
# pyflakes                           2.0.0
# Pygments                           2.2.0
# pygpu                              0.7.6
# pylint                             2.1.1
# pymc                               2.3.6
# Pympler                            0.5
# PyNaCl                             0.3.0
# pyOpenSSL                          18.0.0
# pyparsing                          2.2.0
# pysam                              0.14.1
# pysftp                             0.2.9
# pystan                             2.18.0.0
# pytest                             3.7.1
# pytest-arraydiff                   0.2
# pytest-astropy                     0.4.0
# pytest-doctestplus                 0.1.3
# pytest-openfiles                   0.3.0
# pytest-remotedata                  0.3.0
# python-crfsuite                    0.9.5
# python-dateutil                    2.7.3
# pytools                            2016.2.6
# pytz                               2018.5
# PyWavelets                         0.5.2
# PyYAML                             3.13
# pyzmq                              17.1.0
# QtAwesome                          0.4.4
# qtconsole                          4.3.1
# QtPy                               1.4.2
# redis                              2.10.6
# reportlab                          3.4.0
# requests                           2.14.2
# retrying                           1.3.3
# rope                               0.11.0
# ruamel-yaml                        0.15.46
# s3transfer                         0.1.13
# SAS-kernel                         2.1.0
# saspy                              2.1.4
# scikit-image                       0.14.0
# scikit-learn                       0.19.0
# scikit-sparse                      0.4.3
# scipy                              1.1.0
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# service-identity                   17.0.0
# setuptools                         40.0.0
# Shapely                            1.6.4.post1
# simplegeneric                      0.8.1
# simplejson                         3.8.1
# singledispatch                     3.4.0.3
# six                                1.11.0
# sklearn                            0.0
# smart-open                         1.6.0
# snakemake                          4.0.0
# snakeviz                           0.4.2
# snowballstemmer                    1.2.1
# sockjs-tornado                     1.0.3
# sortedcontainers                   2.0.4
# spectra                            0.0.11
# Sphinx                             1.7.6
# sphinx-rtd-theme                   0.4.1
# sphinxcontrib-websupport           1.1.0
# spyder                             3.2.8
# SQLAlchemy                         1.2.10
# statsmodels                        0.9.0
# sympy                              1.2
# tables                             3.4.4
# tblib                              1.3.2
# tensorboard                        1.8.0
# tensorflow                         1.3.0
# tensorflow-gpu                     1.8.0
# tensorflow-tensorboard             0.4.0
# termcolor                          1.1.0
# terminado                          0.8.1
# testpath                           0.3.1
# Theano                             1.0.2+2.gc449c8699
# toolz                              0.9.0
# tornado                            5.1
# traitlets                          4.3.2
# Twisted                            18.7.0
# twobitreader                       3.1.4
# typed-ast                          1.1.0
# typing                             3.5.2.2
# unicodecsv                         0.14.1
# urllib3                            1.12
# virtualenv                         15.1.0
# wcwidth                            0.1.7
# Werkzeug                           0.14.1
# wheel                              0.31.1
# widgetsnbextension                 3.4.0
# wrapt                              1.10.11
# xlrd                               1.1.0
# XlsxWriter                         1.0.5
# xlwt                               1.3.0
# xopen                              0.3.2
# yarl                               1.2.6
# yt                                 3.4.1
# zict                               0.1.3
# zope.interface                     4.5.0

# %%
# !nvidia-smi
# Out:
# Tue Jun  5 15:54:51 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.48                 Driver Version: 390.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN V             On   | 00000000:83:00.0 Off |                  N/A |
# | 28%   30C    P8    23W / 250W |  11489MiB / 12066MiB |      0%   E. Process |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     12885      C   python                                     11478MiB |
# +-----------------------------------------------------------------------------+

# %%
# !module list
# Out:
# =
# Currently Loaded Modules:
#   1) cuda/9.1         3) python-anaconda-arc-connect/latest
#   2) cudnn/9.1-v7.1   4) R/3.3.3
#
#
#
# >
