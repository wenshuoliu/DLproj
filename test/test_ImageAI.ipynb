# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
from PIL import Image
# %matplotlib inline

# %%
from imageai.Detection import ObjectDetection
# Out:
# Using TensorFlow backend.

# %%
path = '/nfs/turbo/umms-awaljee/wsliu/Data/test/'
data_path = '/nfs/turbo/umms-awaljee/wsliu/Data/test/image_samples/'
model_path = '/nfs/turbo/umms-awaljee/wsliu/Data/test/models/'

# %%
detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath(model_path+'resnet50_coco_best_v2.0.1.h5')

# %%
detector.loadModel()

# %%
images = os.listdir(data_path)

# %%
sorted([n for n in images if not n.startswith('resize_')])
# Out:
# ['IMG_0085.JPG',
#  'IMG_0241.JPG',
#  'IMG_0242.JPG',
#  'IMG_0243.JPG',
#  'IMG_0244.JPG',
#  'IMG_0280.JPG',
#  'IMG_0288.JPG',
#  'IMG_0289.JPG',
#  'IMG_0916.JPG',
#  'IMG_0937.JPG',
#  'IMG_1214.JPG',
#  'IMG_1249.JPG',
#  'IMG_3090.JPG',
#  'IMG_3092.JPG',
#  'IMG_3093.JPG',
#  'IMG_3094.JPG',
#  'IMG_3095.JPG',
#  'IMG_3096.JPG',
#  'IMG_3097.JPG',
#  'IMG_3098.JPG',
#  'IMG_3099.JPG',
#  'IMG_3100.JPG',
#  'IMG_3101.JPG',
#  'IMG_3102.JPG',
#  'IMG_3105.JPG',
#  'IMG_3106.JPG',
#  'IMG_3110.JPG',
#  'IMG_3116.JPG',
#  'IMG_3118.JPG',
#  'IMG_3119.JPG',
#  'google_street_view.PNG',
#  'sample1.jpg',
#  'sample2.jpg',
#  'sample3.jpg',
#  'sample4.jpg']

# %%
for name in images:
    if (not name.startswith('resize_')) and ('resize_'+name not in images):
        img = Image.open(data_path+name)
        img.thumbnail((1000, 1000), Image.ANTIALIAS)
        img.save(data_path+'resize_'+name)

# %%
img = 'sample3.jpg'
detections = detector.detectObjectsFromImage(input_image=data_path+'resize_'+img, output_image_path=path+'detection_output/output_'+img)

# %%
for obj in detections:
    print(obj['name']+':'+obj['percentage_probability'])
# Out:
# chair:62.15919256210327
# chair:52.82064080238342
# tv:79.16321754455566
# person:53.3954381942749
# person:61.799198389053345
# person:74.54477548599243
# person:70.80401182174683
# person:61.27915978431702
# person:72.22450375556946
# chair:53.83707284927368
# dining table:50.060975551605225
# chair:70.33358216285706
# chair:71.08263373374939
# chair:53.04049253463745
# chair:50.4153311252594
# chair:60.10510325431824
# chair:81.80767297744751
# chair:90.72323441505432
# chair:84.4003975391388
# chair:74.33148622512817

# %%
Image.open(data_path+'resize_'+img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x750 at 0x2AC39D093518>

# %%
Image.open(path+'detection_output/output_'+img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x750 at 0x2AC39D0938D0>
